# %% [markdown]
# # ECOv003 JET Accuracy Analysis with ECOv002 Cal-Val - Calibration Comparison
#
# This notebook compares the accuracy of the JET ensemble using ECOSTRESS Collection 2 Cal-Val data **with and without calibration** applied to air temperature (Ta), relative humidity (RH), and soil moisture (SM).
#
# The notebook shows side-by-side comparisons to demonstrate the impact of calibration on model accuracy.

# %% [markdown]
# ## Overview
#
# This notebook demonstrates the impact of calibration on JET ensemble model accuracy by:
#
# 1. **Processing data twice**: Once without calibration (baseline) and once with calibration applied to meteorological inputs (Ta, RH, SM)
# 2. **Creating side-by-side comparisons**: All figures show both uncalibrated (left) and calibrated (right) results
# 3. **Quantifying improvements**: R² and RMSE metrics are shown for both versions to measure calibration effectiveness
#
# The calibration corrects systematic biases in:
# - **Air Temperature (Ta_C)**: Temperature measurements from GEOS-5 FP
# - **Relative Humidity (RH)**: Humidity measurements from GEOS-5 FP
# - **Soil Moisture (SM)**: Soil moisture measurements from SMAP

# %% [markdown]
# ## Import Required Libraries and Functions
#
# This cell imports all necessary libraries and functions for data processing, model execution, statistical analysis, and plotting. It includes custom modules for the JET ensemble, sensitivity analysis, and net radiation calculations, as well as standard scientific Python libraries.

# %%
import sys
import os
sys.path.insert(0, os.path.abspath(os.path.join(os.path.dirname("__file__"), '..')))
from typing import Callable
from os import makedirs
from os.path import join
import numpy as np
import pandas as pd
from verma_net_radiation import verma_net_radiation_table
from JET3 import process_JET_table, load_ECOv002_calval_JET_inputs
from monte_carlo_sensitivity import perturbed_run, sensitivity_analysis, divide_absolute_by_unperturbed, sensitivity_magnitude_barchart
import matplotlib.pyplot as plt
from scipy.stats import mstats
import seaborn as sns
from matplotlib.ticker import FuncFormatter

# %% [markdown]
# ## Configuration Options
#
# Set configuration options for the notebook, including whether to save plots to files.

# %%
# Configuration: Set to True to save plots to files, False to only display them
SAVE_PLOTS = False

# %%
input_variables = [
    "ST_C",
    "NDVI",
    "albedo",
    "Ta_C",
    "RH",
    "AOT",
    "COT",
    "vapor_gccm",
    "ozone_cm",
    "elevation_m",
    "canopy_height_meters"
]

output_variables = [
    "Rn_Wm2",
    "ET_daylight_kg",
    "GPP_inst_g_m2_s"
]

# Per-variable physical bounds to keep perturbations realistic
input_min = {
    "ST_C": 0.0,
    "NDVI": 0.05,
    "albedo": 0.0,
    "Ta_C": 0.0,
    "RH": 0.0,
    "AOT": 0.0,
    "COT": 0.0,
    "vapor_gccm": 0.0,
    "ozone_cm": 0.0,
    "elevation_m": 0.0,
    "canopy_height_meters": 0.0,
}

input_max = {
    "ST_C": 50.0,
    "NDVI": 1,
    "albedo": 1,
}

# %% [markdown]
# ## Define Processing Function for Model Table
#
# This cell defines the forward process for analysis as the BESS-JPL model.

# %%
forward_process = process_JET_table
model_name = "JET"

# %% [markdown]
# ## Set Normalization Function
#
# This cell assigns the normalization function used to compare perturbed model outputs to the unperturbed baseline. The function `divide_absolute_by_unperturbed` is used for normalization in the sensitivity analysis.

# %%
normalization_function = divide_absolute_by_unperturbed

# %% [markdown]
# ## Load and Filter Input Data
#
# This cell loads the ECOSTRESS Cal-Val input data using a custom loader function and filters out surface temperatures greater than 50 Celsius and NDVI values less than 0.05. The resulting DataFrame is displayed for inspection.

# %%
input_df = load_ECOv002_calval_JET_inputs()

# Apply lower and upper bounds from configuration dictionaries
mask = pd.Series(True, index=input_df.index)
for var, min_val in input_min.items():
    if var in input_df.columns:
        mask &= input_df[var] >= min_val
for var, max_val in input_max.items():
    if var in input_df.columns:
        mask &= input_df[var] <= max_val

input_df = input_df[mask]
input_df = input_df.dropna()
input_df
# Out:
#       Unnamed: 0      ID vegetation climate    STICinst   BESSinst  MOD16inst  \
# 15            15  US-xAB        ENF     Csb  141.635670  168.24043  402.81810
# 17            17  US-xAB        ENF     Csb    1.881266  163.94730  301.40400
# 18            18  US-xAB        ENF     Csb    3.135606  246.87700  614.51480
# 19            19  US-xAB        ENF     Csb  311.482820  290.73126  672.27510
# 20            20  US-xAB        ENF     Csb   51.920338   95.28810  116.67136
# ...          ...     ...        ...     ...         ...        ...        ...
# 992          992  US-xML        DBF     Dfb  417.831120  706.93066  523.92740
# 994          994  US-xML        DBF     Dfb  161.558200  306.15277  420.44678
# 1001        1001  US-UiB        CRO     Dfa   93.876100  251.38747  238.71077
# 1020        1020  US-ARM        CRO     Cfa   80.255005    0.00000  180.10085
# 1021        1021  US-ARM        CRO     Cfa  126.236190    0.00000  199.79102
#
#       PTJPLSMinst      ETinst  ETinstUncertainty  ...      CL  Tmin_open  \
# 15      159.71700  139.016083         107.183200  ...  0.0032       8.31
# 17      179.13661  131.273636         106.525215  ...  0.0032       8.31
# 18      405.50497  366.056641         222.890230  ...  0.0032       8.31
# 19      478.82382  439.821228         153.787670  ...  0.0032       8.31
# 20       73.20884  232.693512          24.038680  ...  0.0032       8.31
# ...           ...         ...                ...  ...     ...        ...
# 992     310.69684  356.174072         148.624050  ...  0.0065      11.39
# 994     206.48576  237.659103          98.727560  ...  0.0065      11.39
# 1001    198.90399  106.316444          67.694800  ...  0.0070      12.02
# 1020    211.28325  164.581390          84.672410  ...  0.0070      12.02
# 1021    232.13673  281.860535          89.163790  ...  0.0032       8.31
#
#       Tmin_closed  VPD_open  VPD_closed     Tmin_C  Topt_C  fAPARmax  \
# 15           -8.0     650.0      3000.0  11.940895    6.69    0.6040
# 17           -8.0     650.0      3000.0  11.940895    6.69    0.6040
# 18           -8.0     650.0      3000.0  11.940895    6.69    0.6040
# 19           -8.0     650.0      3000.0  11.940895    6.69    0.6040
# 20           -8.0     650.0      3000.0  11.940895    6.69    0.6040
# ...           ...       ...         ...        ...     ...       ...
# 992          -8.0     650.0      3500.0  27.538052    2.66    0.5404
# 994          -8.0     650.0      3500.0  27.538052    2.66    0.5404
# 1001         -8.0     650.0      4500.0   9.637029    2.58    0.4060
# 1020         -8.0     650.0      4500.0   9.637029    8.48    0.4017
# 1021         -8.0     650.0      3000.0  18.894075    8.48    0.4017
#
#       field_capacity  wilting_point
# 15              0.33           0.16
# 17              0.33           0.16
# 18              0.33           0.16
# 19              0.33           0.16
# 20              0.33           0.16
# ...              ...            ...
# 992             0.34           0.14
# 994             0.34           0.14
# 1001            0.32           0.14
# 1020            0.29           0.12
# 1021            0.29           0.12
#
# [270 rows x 133 columns]

# %% [markdown]
# ## Process Input Data Through Model
#
# This cell applies the processing function to the filtered input data, running it through the model, and displays the resulting DataFrame.

# %%
# Process data WITHOUT calibration
print("Processing WITHOUT calibration...")
processed_uncalibrated = forward_process(input_df, use_calibration=False)
processed_uncalibrated

# Process data WITH calibration  
print("\nProcessing WITH calibration...")
processed_calibrated = forward_process(input_df, use_calibration=True)
processed_calibrated
# Out:
# Processing WITHOUT calibration...
# [2026-02-27 10:40:32 INFO] starting JET table processing
# [2026-02-27 10:40:32 INFO] started extracting geometry from JET input table
# [2026-02-27 10:40:32 INFO] completed extracting geometry from JET input table (0.004 seconds)
# [2026-02-27 10:40:32 INFO] started extracting time from JET input table
# [2026-02-27 10:40:32 INFO] completed extracting time from JET input table (0.001 seconds)
# [2026-02-27 10:40:32 INFO] running Forest Light Environmental Simulator
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [2026-02-27 10:40:32 INFO] completed processing FLiES-ANN in 0.16 seconds
# [2026-02-27 10:40:32 INFO] variable PAR_albedo min: 0.007 mean: 0.055 max: 0.193 nan: 0.00% (nan)
# [2026-02-27 10:40:32 INFO] variable NIR_albedo min: 0.066 mean: 0.162 max: 0.530 nan: 0.00% (nan)
# [2026-02-27 10:40:32 INFO] variable PAR_direct_Wm2 min: 7.148 mean: 269.735 max: 442.463 nan: 0.00% (nan)
# [2026-02-27 10:40:32 INFO] variable SWin_FLiES_ANN min: 163.676 mean: 716.916 max: 1095.605 nan: 0.00% (nan)
# [2026-02-27 10:40:32 INFO] running Breathing Earth System Simulator
# <class 'numpy.ndarray'>
# float32
# [2026-02-27 10:40:32 INFO] variable SZA_deg min: 17.642 mean: 46.017 max: 72.208 nan: 0.00% (nan)
# [2026-02-27 10:40:32 INFO] variable CI min: 0.188 mean: 0.266 max: 0.298 nan: 0.00% (nan)
# [2026-02-27 10:40:32 INFO] variable elevation_m min: 7.300 mean: 1164.656 max: 3504.000 nan: 0.00% (nan)
# [2026-02-27 10:40:32 INFO] variable NDVI_minimum min: -0.017 mean: 0.172 max: 0.569 nan: 0.00% (nan)
# [2026-02-27 10:40:32 INFO] variable NDVI_maximum min: 0.314 mean: 0.585 max: 0.918 nan: 0.00% (nan)
# [2026-02-27 10:40:32 INFO] variable C4_fraction min: 0.000 mean: 0.268 max: 0.939 nan: 0.00% (nan)
# [2026-02-27 10:40:32 INFO] variable carbon_uptake_efficiency (float64) with [0.08       0.08133262 0.08276227 0.08521522 0.08942724 0.09
#  0.09      ] unique values
# [2026-02-27 10:40:32 INFO] * 0.0799999982118606: 107
# [2026-02-27 10:40:32 INFO] * 0.0813326167352959: 32
# [2026-02-27 10:40:32 INFO] * 0.0827622704609846: 2
# [2026-02-27 10:40:32 INFO] * 0.0852152226652387: 62
# [2026-02-27 10:40:32 INFO] * 0.0894272443356804: 10
# [2026-02-27 10:40:32 INFO] * 0.0900000035762786: 41
# [2026-02-27 10:40:32 INFO] * 0.0900000035762787: 16
# [2026-02-27 10:40:32 INFO] variable kn (float64) with [0.41       0.41       0.41       0.44997853 0.49286811 0.56645664
#  0.69281721 0.70999998 0.70999998] unique values
# [2026-02-27 10:40:32 INFO] * 0.4099999964237212: 27
# [2026-02-27 10:40:32 INFO] * 0.4099999964237213: 76
# [2026-02-27 10:40:32 INFO] * 0.4099999964237214: 4
# [2026-02-27 10:40:32 INFO] * 0.449978528297716: 32
# [2026-02-27 10:40:32 INFO] * 0.4928681145041901: 2
# [2026-02-27 10:40:32 INFO] * 0.5664566367696335: 62
# [2026-02-27 10:40:32 INFO] * 0.6928172115661085: 10
# [2026-02-27 10:40:32 INFO] * 0.7099999785423278: 14
# [2026-02-27 10:40:32 INFO] * 0.7099999785423279: 43
# [2026-02-27 10:40:32 INFO] variable peakVCmax_C3_μmolm2s1 min: 62.000 mean: 86.274 max: 132.971 nan: 0.00% (nan)
# [2026-02-27 10:40:32 INFO] variable peakVCmax_C4_μmolm2s1 min: 37.000 mean: 65.034 max: 120.000 nan: 0.00% (nan)
# [2026-02-27 10:40:32 INFO] variable ball_berry_slope_C3 min: 7.500 mean: 8.808 max: 9.500 nan: 0.00% (nan)
# [2026-02-27 10:40:32 INFO] variable ball_berry_slope_C4 min: 4.203 mean: 5.177 max: 5.800 nan: 0.00% (nan)
# [2026-02-27 10:40:32 INFO] variable ball_berry_intercept_C3 min: 0.005 mean: 0.010 max: 0.015 nan: 0.00% (nan)
# [2026-02-27 10:40:32 INFO] variable KG_climate (float32) with [2. 3. 4. 5.] unique values
# [2026-02-27 10:40:32 INFO] * 2.0: 154
# [2026-02-27 10:40:32 INFO] * 3.0: 28
# [2026-02-27 10:40:32 INFO] * 4.0: 86
# [2026-02-27 10:40:32 INFO] * 5.0: 2
# [2026-02-27 10:40:32 INFO] variable canopy_height_meters min: 0.000 mean: 3.962 max: 25.743 nan: 0.00% (nan)
# [2026-02-27 10:40:32 INFO] All GEOS-5 FP inputs provided, no retrieval needed.
# [2026-02-27 10:40:32 INFO] variable canopy_temperature_C min: 3.730 mean: 30.458 max: 49.990 nan: 0.00% (nan)
# [2026-02-27 10:40:32 INFO] variable soil_temperature_C min: 3.730 mean: 30.458 max: 49.990 nan: 0.00% (nan)
# [2026-02-27 10:40:32 INFO] using given FLiES output as BESS parameters
# [2026-02-27 10:40:33 INFO] variable Ps_Pa min: 66823.360 mean: 88555.415 max: 101241.460 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable VPD_Pa min: 189.019 mean: 1796.608 max: 3845.601 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable RH min: 0.273 mean: 0.387 max: 0.874 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable desTa min: 49.999 mean: 173.694 max: 318.308 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ddesTa min: 3.165 mean: 9.054 max: 15.194 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable gamma min: 44.648 mean: 58.961 max: 68.139 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Cp min: 1006.679 mean: 1012.269 max: 1019.788 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable rhoa min: 0.776 mean: 1.045 max: 1.231 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable epsa min: 0.679 mean: 0.765 max: 0.966 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable R min: 14.018 mean: 108.103 max: 1000.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Rc min: 14.018 mean: 108.103 max: 1000.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Rs min: 7.009 mean: 54.052 max: 500.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable SFd min: 0.020 mean: 0.051 max: 0.077 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable SFd2 min: 0.172 mean: 0.334 max: 0.983 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable DL min: 8.245 mean: 11.401 max: 14.086 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Ra min: 416.618 mean: 888.643 max: 1240.699 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable fStress min: 0.012 mean: 0.239 max: 0.975 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable VCmax_C3_sunlit_μmolm2s1 min: 2.423 mean: 27.344 max: 141.877 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable VCmax_C4_sunlit_μmolm2s1 min: 1.561 mean: 22.475 max: 141.877 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable VCmax_C3_shaded_μmolm2s1 min: 0.097 mean: 23.447 max: 215.178 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable VCmax_C4_shaded_μmolm2s1 min: 0.069 mean: 21.750 max: 215.178 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable PARDiff min: 18.773 mean: 43.453 max: 194.457 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable PARDir min: 7.148 mean: 269.735 max: 442.463 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable NIRDiff min: 0.000 mean: 25.057 max: 346.098 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable NIRDir min: 0.004 mean: 337.810 max: 559.698 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable UV min: 12.171 mean: 42.068 max: 67.767 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable SZA min: 17.642 mean: 46.017 max: 72.208 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LAI min: 0.158 mean: 0.984 max: 4.031 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable CI min: 0.188 mean: 0.266 max: 0.298 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable albedo_visible min: 0.007 mean: 0.055 max: 0.193 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable albedo_NIR min: 0.066 mean: 0.162 max: 0.530 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable kb min: 0.525 mean: 0.799 max: 1.636 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable kk_Pb min: 0.483 mean: 0.735 max: 1.505 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable kk_Nb min: 0.219 mean: 0.334 max: 0.685 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable kk_Nd (float64) with [0.1464155] unique values
# [2026-02-27 10:40:33 INFO] * 0.14641550464346323: 1
# [2026-02-27 10:40:33 INFO] variable fSun min: 0.124 mean: 0.244 max: 0.291 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable L_CI min: 0.043 mean: 0.247 max: 1.122 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable exp_kk_Pd_L_CI min: 0.446 mean: 0.849 max: 0.969 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable exp_kk_Nd_L_CI min: 0.848 mean: 0.965 max: 0.994 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APARin_Wm2 min: 8.569 mean: 41.813 max: 170.184 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APARin_sunlit_Wm2 min: 1.007 mean: 32.045 max: 136.513 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APARin_diffuse_Wm2 min: 0.767 mean: 6.096 max: 77.708 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APARin_scattered_sunlit_Wm2 min: 0.000 mean: 2.173 max: 11.388 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APARin_sunlit_Wm2 min: 8.539 mean: 40.314 max: 159.493 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APARin_shade_Wm2 min: 0.000 mean: 1.520 max: 21.547 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable PARin_soil_Wm2 min: 46.064 mean: 253.775 max: 416.477 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APAR_Soil min: 39.155 mean: 215.709 max: 354.006 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APARout_sunlit_Wm2 min: 3.480 mean: 33.028 max: 59.956 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APARout_shade_Wm2 min: 0.851 mean: 5.038 max: 19.194 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APAR_sunlit_Wm2 min: 20.735 mean: 73.342 max: 178.973 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APAR_shade_Wm2 min: 0.881 mean: 6.558 max: 35.881 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ANIRin_sunlit_Wm2 min: 2.116 mean: 17.331 max: 69.243 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ANIRin_shade_Wm2 min: 0.027 mean: 1.608 max: 17.031 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable NIRin_soil_Wm2 min: 49.513 mean: 285.011 max: 473.986 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ANIR_soil_Wm2 min: 34.659 mean: 199.508 max: 331.790 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ANIRout_sunlit_Wm2 min: 14.165 mean: 82.822 max: 138.350 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ANIRout_Wm2 min: 0.393 mean: 2.681 max: 12.212 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ANIR_sunlit_Wm2 min: 16.376 mean: 100.154 max: 157.935 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ANIR_shade_Wm2 min: 0.455 mean: 4.289 max: 25.313 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable G_Wm2 min: 10.963 mean: 60.398 max: 99.122 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ASW_sunlit_Wm2 min: 41.082 mean: 173.889 max: 328.660 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ASW_shade_Wm2 min: 1.524 mean: 12.294 max: 74.405 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ASW_soil_Wm2 min: 102.391 mean: 453.340 max: 736.557 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APAR_sunlit_Wm2 min: 20.735 mean: 73.342 max: 178.973 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APAR_sunlit_μmolm2s1 min: 94.554 mean: 334.438 max: 816.116 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APAR_shade_Wm2 min: 0.881 mean: 6.558 max: 35.881 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APAR_shade_μmolm2s1 min: 4.019 mean: 29.905 max: 163.617 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable fSun min: 0.124 mean: 0.244 max: 0.291 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APAR_sunlit_μmolm2s1 min: 94.554 mean: 334.438 max: 816.116 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APAR_shade_μmolm2s1 min: 4.019 mean: 29.905 max: 163.617 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ASW_sunlit_Wm2 min: 41.082 mean: 173.889 max: 328.660 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ASW_shade_Wm2 min: 1.524 mean: 12.294 max: 74.405 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ASW_soil_Wm2 min: 102.391 mean: 453.340 max: 736.557 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable G_Wm2 min: 10.963 mean: 60.398 max: 99.122 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable GPP_C3 min: 0.051 mean: 6.301 max: 34.198 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_C3 min: 3.656 mean: 85.030 max: 368.944 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_soil_C3 min: 2.517 mean: 42.377 max: 175.729 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_canopy_C3 min: 0.000 mean: 42.653 max: 228.694 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Rn_C3 min: 67.033 mean: 426.438 max: 815.548 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Rn_soil_C3 min: 67.033 mean: 338.052 max: 626.474 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Rn_canopy_C3 min: 0.000 mean: 88.386 max: 279.934 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable GPP_C4 min: 0.000 mean: 9.799 max: 50.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_C4 min: 3.641 mean: 87.778 max: 369.445 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_soil_C4 min: 2.517 mean: 42.377 max: 175.729 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_canopy_C4 min: 0.000 mean: 45.401 max: 231.061 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Rn_C4 min: 67.033 mean: 426.438 max: 815.548 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Rn_soil_C4 min: 67.033 mean: 338.052 max: 626.474 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Rn_canopy_C4 min: 0.000 mean: 88.386 max: 279.934 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] started daylight ET upscaling
# [2026-02-27 10:40:33 INFO] completed daylight ET upscaling (elapsed: 0.01 seconds)
# [2026-02-27 10:40:33 INFO] completed processing BESS-JPL in 0.09 seconds
# [2026-02-27 10:40:33 INFO] variable Rn_BESS_Wm2 min: 67.033 mean: 426.438 max: 815.548 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Rn_BESS_Wm2 min: 67.033 mean: 426.438 max: 815.548 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_BESS_Wm2 min: 3.648 mean: 86.108 max: 368.953 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] calculating solar day of year
# [2026-02-27 10:40:33 INFO] calculating solar hour of day
# [2026-02-27 10:40:33 INFO] calculating daylight hours and sunrise hour
# [2026-02-27 10:40:33 INFO] variable LE_BESS_Wm2 min: 3.648 mean: 86.108 max: 368.953 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable GPP_inst_umol_m2_s min: 0.006 mean: 6.632 max: 39.888 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] starting Verma net radiation processing
# [2026-02-27 10:40:33 INFO] variable SWout_Wm2 min: 9.139 mean: 79.449 max: 298.413 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable SWnet_Wm2 min: 149.392 mean: 637.467 max: 1000.028 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LWin_Wm2 min: 227.974 mean: 339.497 max: 440.770 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LWout_Wm2 min: 316.593 mean: 469.764 max: 596.879 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Rn_Wm2 min: 57.448 mean: 507.201 max: 858.158 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] Verma net radiation processing complete in 0.01 seconds
# [2026-02-27 10:40:33 INFO] running Surface Temperature Initiated Closure
# [2026-02-27 10:40:33 INFO] variable Ms min: 0.000 mean: 0.194 max: 0.691 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] running STIC iteration 1 / 3
# [2026-02-27 10:40:33 INFO] using variable Priestley-Taylor alpha with mean: 1.2
# [2026-02-27 10:40:33 INFO] completed STIC iteration 1 / 3 with max LE change: 316.084 (0.0009974999993573874 seconds)
# [2026-02-27 10:40:33 INFO] variable SM_1 min: 0.000 mean: 0.104 max: 0.691 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable G_1 min: 2.904 mean: 69.742 max: 177.794 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_1 min: 3.011 mean: 217.767 max: 599.531 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] running STIC iteration 2 / 3
# [2026-02-27 10:40:33 INFO] using variable Priestley-Taylor alpha with mean: 1.274
# [2026-02-27 10:40:33 INFO] completed STIC iteration 2 / 3 with max LE change: 53.859 (0.005868541993550025 seconds)
# [2026-02-27 10:40:33 INFO] variable SM_2 min: 0.000 mean: 0.111 max: 0.913 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable G_2 min: 2.904 mean: 69.742 max: 177.794 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_2 min: 3.011 mean: 219.485 max: 608.879 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] running STIC iteration 3 / 3
# [2026-02-27 10:40:33 INFO] using variable Priestley-Taylor alpha with mean: 1.523
# [2026-02-27 10:40:33 INFO] completed STIC iteration 3 / 3 with max LE change: 43.815 (0.01871970899810549 seconds)
# [2026-02-27 10:40:33 INFO] variable SM_3 min: 0.000 mean: 0.105 max: 0.691 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable G_3 min: 2.904 mean: 69.742 max: 177.794 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_3 min: 3.011 mean: 221.034 max: 627.770 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] started daily ET upscaling (STIC-JPL)
# [2026-02-27 10:40:33 INFO] completed daily ET upscaling (elapsed: 0.01 seconds)
# [2026-02-27 10:40:33 INFO] completed processing STIC-JPL in 0.05 seconds
# [2026-02-27 10:40:33 INFO] variable LE_STIC_Wm2 min: 3.011 mean: 221.034 max: 627.770 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ET_daylight_STIC_kg min: 0.045 mean: 3.113 max: 7.688 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_canoy_STIC_Wm2 min: 3.011 mean: 168.509 max: 498.187 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable G_STIC_Wm2 min: 2.904 mean: 69.742 max: 177.794 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_canopy_fraction_STIC min: 0.199 mean: 0.778 max: 1.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] running Priestley-Taylor JPL with Soil Moisture
# [2026-02-27 10:40:33 INFO] starting PT-JPL-SM model run
# [2026-02-27 10:40:33 INFO] using given optimum temperature (Topt_C)
# [2026-02-27 10:40:33 INFO] variable Topt_C min: 0.000 mean: 8.838 max: 20.450 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable fAPARmax min: 0.233 mean: 0.369 max: 0.604 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] using given air temperature (Ta_C)
# [2026-02-27 10:40:33 INFO] variable Ta_C min: 1.853 mean: 22.343 max: 35.512 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] using given relative humidity (RH)
# [2026-02-27 10:40:33 INFO] variable RH min: 0.273 mean: 0.388 max: 0.874 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] using given soil moisture (SM)
# [2026-02-27 10:40:33 INFO] variable soil_moisture min: 0.033 mean: 0.144 max: 0.664 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] using given field capacity
# [2026-02-27 10:40:33 INFO] variable field_capacity min: 0.190 mean: 0.273 max: 0.380 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] using given wilting point
# [2026-02-27 10:40:33 INFO] variable wilting_point min: 0.040 mean: 0.116 max: 0.160 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] using given canopy height
# [2026-02-27 10:40:33 INFO] variable canopy_height_meters min: 0.000 mean: 3.962 max: 25.743 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] using given net radiation (Rn_Wm2) for PT-JPL-SM processing
# [2026-02-27 10:40:33 INFO] variable Rn_Wm2 min: 57.448 mean: 507.201 max: 858.158 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] using given soil heat flux (G_Wm2)
# [2026-02-27 10:40:33 INFO] variable G min: 2.904 mean: 69.742 max: 177.794 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable fwet min: 0.006 mean: 0.032 max: 0.583 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable fREW min: 0.000 mean: 0.338 max: 1.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Topt_C min: 0.000 mean: 8.838 max: 20.450 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Topt_C min: 4.966 mean: 22.932 max: 35.512 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable epsilon min: 0.430 mean: 0.704 max: 0.827 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Rn_soil_Wm2 min: 18.659 mean: 318.255 max: 658.596 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_soil_Wm2 min: 0.591 mean: 55.420 max: 354.354 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Rn_canopy_Wm2 min: 24.668 mean: 188.946 max: 728.300 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable PET min: 48.180 mean: 391.163 max: 730.760 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable fTRM min: 0.147 mean: 0.834 max: 1.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_canopy_Wm2 min: 8.542 mean: 128.508 max: 518.078 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_interception_Wm2 min: 0.131 mean: 7.519 max: 108.141 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_Wm2 min: 10.737 mean: 191.447 max: 631.294 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] started daylight ET upscaling
# [2026-02-27 10:40:33 INFO] completed daylight ET upscaling (elapsed: 0.01 seconds)
# [2026-02-27 10:40:33 INFO] PT-JPL-SM model run complete (elapsed: 0.03 seconds)
# [2026-02-27 10:40:33 INFO] completed processing PT-JPL-SM in 0.03 seconds
# [2026-02-27 10:40:33 INFO] variable LE_PTJPLSM_Wm2 min: 10.737 mean: 191.447 max: 631.294 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ET_daylight_PTJPLSM_kg min: 0.115 mean: 2.628 max: 8.370 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable G_PTJPLSM min: 2.904 mean: 69.742 max: 177.794 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable EF_PTJPLSM min: 0.036 mean: 0.418 max: 0.964 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_canopy_PTJPLSM_Wm2 min: 8.542 mean: 128.508 max: 518.078 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_canopy_fraction_PTJPLSM min: 0.101 mean: 0.746 max: 0.976 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_soil_PTJPLSM_Wm2 min: 0.591 mean: 55.420 max: 354.354 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_soil_fraction_PTJPLSM min: 0.002 mean: 0.219 max: 0.889 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_interception_PTJPLSM_Wm2 min: 0.131 mean: 7.519 max: 108.141 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_interception_fraction_PTJPLSM min: 0.002 mean: 0.034 max: 0.571 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable PET_instantaneous_PTJPLSM_Wm2 min: 48.180 mean: 391.163 max: 730.760 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ESI_PTJPLSM min: 0.067 mean: 0.476 max: 1.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] running Penman-Monteith JPL
# [2026-02-27 10:40:33 INFO] variable Ta_C min: 1.853 mean: 22.343 max: 35.512 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Tmin_C min: 0.122 mean: 8.538 max: 27.538 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable IGBP (float32) with [ 1.  4.  5.  7.  8.  9. 10. 12.] unique values
# [2026-02-27 10:40:33 INFO] * 1.0: 23
# [2026-02-27 10:40:33 INFO] * 4.0: 16
# [2026-02-27 10:40:33 INFO] * 5.0: 5
# [2026-02-27 10:40:33 INFO] * 7.0: 37
# [2026-02-27 10:40:33 INFO] * 8.0: 52
# [2026-02-27 10:40:33 INFO] * 9.0: 5
# [2026-02-27 10:40:33 INFO] * 10.0: 126
# [2026-02-27 10:40:33 INFO] * 12.0: 6
# [2026-02-27 10:40:33 INFO] using given net radiation (Rn_Wm2) for PM-JPL processing
# [2026-02-27 10:40:33 INFO] variable Rn_Wm2 min: 57.448 mean: 507.201 max: 858.158 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable G_Wm2 min: 2.904 mean: 69.742 max: 177.794 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] calculating PM-MOD meteorology
# [2026-02-27 10:40:33 INFO] variable specific_humidity min: 0.002 mean: 0.006 max: 0.016 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable rho_kgm3 min: 1.138 mean: 1.396 max: 1.871 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Cp_Jkg min: 1006.341 mean: 1010.011 max: 1018.542 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable delta_Pa min: 50.019 mean: 173.357 max: 317.414 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable fwet (float32) with [1.000000e-04 4.026427e-01 5.832788e-01] unique values
# [2026-02-27 10:40:33 INFO] * 1e-04: 268
# [2026-02-27 10:40:33 INFO] * 0.4026427: 1
# [2026-02-27 10:40:33 INFO] * 0.5832788: 1
# [2026-02-27 10:40:33 INFO] calculating PM-MOD resistances
# [2026-02-27 10:40:33 INFO] variable gl_sh (float32) with [0.01 0.02 0.04 0.08] unique values
# [2026-02-27 10:40:33 INFO] * 0.01: 16
# [2026-02-27 10:40:33 INFO] * 0.02: 132
# [2026-02-27 10:40:33 INFO] * 0.04: 65
# [2026-02-27 10:40:33 INFO] * 0.08: 57
# [2026-02-27 10:40:33 INFO] variable rhc (float64) with [  11.69617938   75.07097703 2000.        ] unique values
# [2026-02-27 10:40:33 INFO] * 11.696179377858375: 1
# [2026-02-27 10:40:33 INFO] * 75.07097702744541: 1
# [2026-02-27 10:40:33 INFO] * 2000.0: 268
# [2026-02-27 10:40:33 INFO] variable rrc min: 173.391 mean: 241.785 max: 327.865 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable rhrc min: 11.163 mean: 214.174 max: 281.687 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable gl_e_wv (float32) with [0.01 0.02 0.04 0.08] unique values
# [2026-02-27 10:40:33 INFO] * 0.01: 16
# [2026-02-27 10:40:33 INFO] * 0.02: 132
# [2026-02-27 10:40:33 INFO] * 0.04: 65
# [2026-02-27 10:40:33 INFO] * 0.08: 57
# [2026-02-27 10:40:33 INFO] variable rvc (float64) with [  11.69617938   75.07097703 2000.        ] unique values
# [2026-02-27 10:40:33 INFO] * 11.696179377858375: 1
# [2026-02-27 10:40:33 INFO] * 75.07097702744541: 1
# [2026-02-27 10:40:33 INFO] * 2000.0: 268
# [2026-02-27 10:40:33 INFO] variable Ac min: 45.895 mean: 305.440 max: 858.158 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_interception_Wm2 min: 0.001 mean: 0.916 max: 134.133 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable rcorr min: 0.917 mean: 1.157 max: 1.534 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable CL (float32) with [0.0025 0.0028 0.0032 0.0065 0.007 ] unique values
# [2026-02-27 10:40:33 INFO] * 0.0025: 5
# [2026-02-27 10:40:33 INFO] * 0.0028: 16
# [2026-02-27 10:40:33 INFO] * 0.0032: 23
# [2026-02-27 10:40:33 INFO] * 0.0065: 94
# [2026-02-27 10:40:33 INFO] * 0.007: 132
# [2026-02-27 10:40:33 INFO] variable Tmin_open (float32) with [ 8.31  8.8   9.5   9.94 11.39 12.02] unique values
# [2026-02-27 10:40:33 INFO] * 8.31: 23
# [2026-02-27 10:40:33 INFO] * 8.8: 37
# [2026-02-27 10:40:33 INFO] * 9.5: 5
# [2026-02-27 10:40:33 INFO] * 9.94: 16
# [2026-02-27 10:40:33 INFO] * 11.39: 57
# [2026-02-27 10:40:33 INFO] * 12.02: 132
# [2026-02-27 10:40:33 INFO] variable Tmin_closed (float32) with [-8. -7. -6.] unique values
# [2026-02-27 10:40:33 INFO] * -8.0: 249
# [2026-02-27 10:40:33 INFO] * -7.0: 5
# [2026-02-27 10:40:33 INFO] * -6.0: 16
# [2026-02-27 10:40:33 INFO] variable Tmin_C min: 0.122 mean: 8.538 max: 27.538 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable mTmin min: 0.384 mean: 0.819 max: 1.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable VPD_open (float32) with [650.] unique values
# [2026-02-27 10:40:33 INFO] * 650.0: 270
# [2026-02-27 10:40:33 INFO] variable VPD_closed (float32) with [2900. 3000. 3500. 3600. 4200. 4400. 4500.] unique values
# [2026-02-27 10:40:33 INFO] * 2900.0: 21
# [2026-02-27 10:40:33 INFO] * 3000.0: 23
# [2026-02-27 10:40:33 INFO] * 3500.0: 52
# [2026-02-27 10:40:33 INFO] * 3600.0: 5
# [2026-02-27 10:40:33 INFO] * 4200.0: 126
# [2026-02-27 10:40:33 INFO] * 4400.0: 37
# [2026-02-27 10:40:33 INFO] * 4500.0: 6
# [2026-02-27 10:40:33 INFO] variable mVPD min: 0.000 mean: 0.646 max: 1.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable gs1 min: 0.000 mean: 0.004 max: 0.009 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Gcu min: 0.000 mean: 0.000 max: 0.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Cc min: 0.001 mean: 0.003 max: 0.020 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable rs min: 51.091 mean: 739.841 max: 2000.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable rh min: 51.091 mean: 739.841 max: 2000.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable rr min: 173.391 mean: 241.785 max: 327.865 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ra min: 11.659 mean: 32.332 max: 71.565 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_canopy_Wm2 min: 3.944 mean: 93.203 max: 477.694 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable RBL_max (float32) with [ 45.  50.  55.  95. 100.] unique values
# [2026-02-27 10:40:33 INFO] * 45.0: 57
# [2026-02-27 10:40:33 INFO] * 50.0: 132
# [2026-02-27 10:40:33 INFO] * 55.0: 37
# [2026-02-27 10:40:33 INFO] * 95.0: 28
# [2026-02-27 10:40:33 INFO] * 100.0: 16
# [2026-02-27 10:40:33 INFO] variable RBL_min (float32) with [20. 25. 65.] unique values
# [2026-02-27 10:40:33 INFO] * 20.0: 169
# [2026-02-27 10:40:33 INFO] * 25.0: 57
# [2026-02-27 10:40:33 INFO] * 65.0: 44
# [2026-02-27 10:40:33 INFO] variable rtotc min: 23.108 mean: 47.034 max: 100.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable rtot min: 23.037 mean: 53.851 max: 127.327 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable rrs min: 173.391 mean: 241.785 max: 327.865 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ras min: 20.335 mean: 43.237 max: 91.711 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Asoil min: 0.000 mean: 142.744 max: 461.811 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable wet_soil_evaporation_Wm2 min: 0.000 mean: 0.021 max: 0.066 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable potential_soil_evaporation_Wm2 min: 0.000 mean: 208.336 max: 660.724 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable fSM min: 0.000 mean: 0.018 max: 0.881 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_soil_Wm2 min: 0.000 mean: 0.676 max: 35.851 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_Wm2 min: 6.339 mean: 94.697 max: 477.719 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] started daylight ET upscaling (PMJPL)
# [2026-02-27 10:40:33 INFO] completed daylight ET upscaling (PMJPL)
# [2026-02-27 10:40:33 INFO] completed processing PM-JPL in 0.06 seconds
# [2026-02-27 10:40:33 INFO] variable LE_PMJPL_Wm2 min: 6.339 mean: 94.697 max: 477.719 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ET_daylight_PMJPL_kg min: 0.064 mean: 1.330 max: 6.334 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable G_PMJPL_Wm2 min: 2.904 mean: 69.742 max: 177.794 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ET_daylight_kg min: 0.383 mean: 1.870 max: 5.972 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] JET table processing complete (0.471 seconds)
#
# Processing WITH calibration...
# [2026-02-27 10:40:33 INFO] starting JET table processing
# [2026-02-27 10:40:33 INFO] started extracting geometry from JET input table
# [2026-02-27 10:40:33 INFO] completed extracting geometry from JET input table (0.008 seconds)
# [2026-02-27 10:40:33 INFO] started extracting time from JET input table
# [2026-02-27 10:40:33 INFO] completed extracting time from JET input table (0.000 seconds)
# [2026-02-27 10:40:33 INFO] applying calibration
# [2026-02-27 10:40:33 INFO] calibrating Ta_C
# [2026-02-27 10:40:33 INFO] calibrating RH
# [2026-02-27 10:40:33 INFO] calibrating soil moisture
# [2026-02-27 10:40:33 INFO] running Forest Light Environmental Simulator
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [2026-02-27 10:40:33 INFO] completed processing FLiES-ANN in 0.13 seconds
# [2026-02-27 10:40:33 INFO] variable PAR_albedo min: 0.007 mean: 0.055 max: 0.193 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable NIR_albedo min: 0.066 mean: 0.162 max: 0.530 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable PAR_direct_Wm2 min: 7.148 mean: 269.735 max: 442.463 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable SWin_FLiES_ANN min: 163.676 mean: 716.916 max: 1095.605 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] running Breathing Earth System Simulator
# <class 'numpy.ndarray'>
# float32
# [2026-02-27 10:40:33 INFO] variable SZA_deg min: 17.642 mean: 46.017 max: 72.208 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable CI min: 0.188 mean: 0.266 max: 0.298 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable elevation_m min: 7.300 mean: 1164.656 max: 3504.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable NDVI_minimum min: -0.017 mean: 0.172 max: 0.569 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable NDVI_maximum min: 0.314 mean: 0.585 max: 0.918 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable C4_fraction min: 0.000 mean: 0.268 max: 0.939 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable carbon_uptake_efficiency (float64) with [0.08       0.08133262 0.08276227 0.08521522 0.08942724 0.09
#  0.09      ] unique values
# [2026-02-27 10:40:33 INFO] * 0.0799999982118606: 107
# [2026-02-27 10:40:33 INFO] * 0.0813326167352959: 32
# [2026-02-27 10:40:33 INFO] * 0.0827622704609846: 2
# [2026-02-27 10:40:33 INFO] * 0.0852152226652387: 62
# [2026-02-27 10:40:33 INFO] * 0.0894272443356804: 10
# [2026-02-27 10:40:33 INFO] * 0.0900000035762786: 41
# [2026-02-27 10:40:33 INFO] * 0.0900000035762787: 16
# [2026-02-27 10:40:33 INFO] variable kn (float64) with [0.41       0.41       0.41       0.44997853 0.49286811 0.56645664
#  0.69281721 0.70999998 0.70999998] unique values
# [2026-02-27 10:40:33 INFO] * 0.4099999964237212: 27
# [2026-02-27 10:40:33 INFO] * 0.4099999964237213: 76
# [2026-02-27 10:40:33 INFO] * 0.4099999964237214: 4
# [2026-02-27 10:40:33 INFO] * 0.449978528297716: 32
# [2026-02-27 10:40:33 INFO] * 0.4928681145041901: 2
# [2026-02-27 10:40:33 INFO] * 0.5664566367696335: 62
# [2026-02-27 10:40:33 INFO] * 0.6928172115661085: 10
# [2026-02-27 10:40:33 INFO] * 0.7099999785423278: 14
# [2026-02-27 10:40:33 INFO] * 0.7099999785423279: 43
# [2026-02-27 10:40:33 INFO] variable peakVCmax_C3_μmolm2s1 min: 62.000 mean: 86.274 max: 132.971 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable peakVCmax_C4_μmolm2s1 min: 37.000 mean: 65.034 max: 120.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ball_berry_slope_C3 min: 7.500 mean: 8.808 max: 9.500 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ball_berry_slope_C4 min: 4.203 mean: 5.177 max: 5.800 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ball_berry_intercept_C3 min: 0.005 mean: 0.010 max: 0.015 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable KG_climate (float32) with [2. 3. 4. 5.] unique values
# [2026-02-27 10:40:33 INFO] * 2.0: 154
# [2026-02-27 10:40:33 INFO] * 3.0: 28
# [2026-02-27 10:40:33 INFO] * 4.0: 86
# [2026-02-27 10:40:33 INFO] * 5.0: 2
# [2026-02-27 10:40:33 INFO] variable canopy_height_meters min: 0.000 mean: 3.962 max: 25.743 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] All GEOS-5 FP inputs provided, no retrieval needed.
# [2026-02-27 10:40:33 INFO] variable canopy_temperature_C min: 3.730 mean: 30.458 max: 49.990 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable soil_temperature_C min: 3.730 mean: 30.458 max: 49.990 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] using given FLiES output as BESS parameters
# [2026-02-27 10:40:33 INFO] variable Ps_Pa min: 66200.123 mean: 88490.286 max: 101241.440 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable VPD_Pa min: 128.319 mean: 2027.255 max: 4822.424 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable RH min: 0.071 mean: 0.261 max: 0.917 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable desTa min: 47.194 mean: 162.714 max: 329.364 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ddesTa min: 3.011 mean: 8.571 max: 15.633 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable gamma min: 43.962 mean: 58.854 max: 68.187 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Cp min: 1006.391 mean: 1009.535 max: 1019.943 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable rhoa min: 0.786 mean: 1.048 max: 1.223 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable epsa min: 0.669 mean: 0.729 max: 0.964 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable R min: 14.018 mean: 108.103 max: 1000.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Rc min: 14.018 mean: 108.103 max: 1000.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Rs min: 7.009 mean: 54.052 max: 500.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable SFd min: 0.020 mean: 0.051 max: 0.077 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable SFd2 min: 0.172 mean: 0.334 max: 0.983 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable DL min: 8.245 mean: 11.401 max: 14.086 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Ra min: 416.618 mean: 888.643 max: 1240.699 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable fStress min: 0.000 mean: 0.153 max: 0.989 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable VCmax_C3_sunlit_μmolm2s1 min: 2.423 mean: 27.344 max: 141.877 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable VCmax_C4_sunlit_μmolm2s1 min: 1.561 mean: 22.475 max: 141.877 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable VCmax_C3_shaded_μmolm2s1 min: 0.097 mean: 23.447 max: 215.178 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable VCmax_C4_shaded_μmolm2s1 min: 0.069 mean: 21.750 max: 215.178 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable PARDiff min: 18.773 mean: 43.453 max: 194.457 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable PARDir min: 7.148 mean: 269.735 max: 442.463 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable NIRDiff min: 0.000 mean: 25.057 max: 346.098 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable NIRDir min: 0.004 mean: 337.810 max: 559.698 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable UV min: 12.171 mean: 42.068 max: 67.767 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable SZA min: 17.642 mean: 46.017 max: 72.208 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LAI min: 0.158 mean: 0.984 max: 4.031 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable CI min: 0.188 mean: 0.266 max: 0.298 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable albedo_visible min: 0.007 mean: 0.055 max: 0.193 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable albedo_NIR min: 0.066 mean: 0.162 max: 0.530 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable kb min: 0.525 mean: 0.799 max: 1.636 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable kk_Pb min: 0.483 mean: 0.735 max: 1.505 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable kk_Nb min: 0.219 mean: 0.334 max: 0.685 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable kk_Nd (float64) with [0.1464155] unique values
# [2026-02-27 10:40:33 INFO] * 0.14641550464346323: 1
# [2026-02-27 10:40:33 INFO] variable fSun min: 0.124 mean: 0.244 max: 0.291 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable L_CI min: 0.043 mean: 0.247 max: 1.122 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable exp_kk_Pd_L_CI min: 0.446 mean: 0.849 max: 0.969 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable exp_kk_Nd_L_CI min: 0.848 mean: 0.965 max: 0.994 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APARin_Wm2 min: 8.569 mean: 41.813 max: 170.184 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APARin_sunlit_Wm2 min: 1.007 mean: 32.045 max: 136.513 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APARin_diffuse_Wm2 min: 0.767 mean: 6.096 max: 77.708 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APARin_scattered_sunlit_Wm2 min: 0.000 mean: 2.173 max: 11.388 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APARin_sunlit_Wm2 min: 8.539 mean: 40.314 max: 159.493 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APARin_shade_Wm2 min: 0.000 mean: 1.520 max: 21.547 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable PARin_soil_Wm2 min: 46.064 mean: 253.775 max: 416.477 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APAR_Soil min: 39.155 mean: 215.709 max: 354.006 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APARout_sunlit_Wm2 min: 3.480 mean: 33.028 max: 59.956 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APARout_shade_Wm2 min: 0.851 mean: 5.038 max: 19.194 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APAR_sunlit_Wm2 min: 20.735 mean: 73.342 max: 178.973 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APAR_shade_Wm2 min: 0.881 mean: 6.558 max: 35.881 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ANIRin_sunlit_Wm2 min: 2.116 mean: 17.331 max: 69.243 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ANIRin_shade_Wm2 min: 0.027 mean: 1.608 max: 17.031 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable NIRin_soil_Wm2 min: 49.513 mean: 285.011 max: 473.986 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ANIR_soil_Wm2 min: 34.659 mean: 199.508 max: 331.790 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ANIRout_sunlit_Wm2 min: 14.165 mean: 82.822 max: 138.350 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ANIRout_Wm2 min: 0.393 mean: 2.681 max: 12.212 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ANIR_sunlit_Wm2 min: 16.376 mean: 100.154 max: 157.935 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ANIR_shade_Wm2 min: 0.455 mean: 4.289 max: 25.313 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable G_Wm2 min: 10.963 mean: 60.398 max: 99.122 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ASW_sunlit_Wm2 min: 41.082 mean: 173.889 max: 328.660 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ASW_shade_Wm2 min: 1.524 mean: 12.294 max: 74.405 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ASW_soil_Wm2 min: 102.391 mean: 453.340 max: 736.557 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APAR_sunlit_Wm2 min: 20.735 mean: 73.342 max: 178.973 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APAR_sunlit_μmolm2s1 min: 94.554 mean: 334.438 max: 816.116 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APAR_shade_Wm2 min: 0.881 mean: 6.558 max: 35.881 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APAR_shade_μmolm2s1 min: 4.019 mean: 29.905 max: 163.617 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable fSun min: 0.124 mean: 0.244 max: 0.291 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APAR_sunlit_μmolm2s1 min: 94.554 mean: 334.438 max: 816.116 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable APAR_shade_μmolm2s1 min: 4.019 mean: 29.905 max: 163.617 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ASW_sunlit_Wm2 min: 41.082 mean: 173.889 max: 328.660 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ASW_shade_Wm2 min: 1.524 mean: 12.294 max: 74.405 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ASW_soil_Wm2 min: 102.391 mean: 453.340 max: 736.557 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable G_Wm2 min: 10.963 mean: 60.398 max: 99.122 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable GPP_C3 min: 0.051 mean: 6.300 max: 34.198 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_C3 min: 0.219 mean: 60.447 max: 381.945 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_soil_C3 min: 0.000 mean: 25.422 max: 183.688 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_canopy_C3 min: 0.000 mean: 35.025 max: 222.866 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Rn_C3 min: 49.119 mean: 398.425 max: 748.335 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Rn_soil_C3 min: 49.119 mean: 321.526 max: 605.894 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Rn_canopy_C3 min: 0.000 mean: 76.899 max: 267.313 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable GPP_C4 min: 0.000 mean: 9.799 max: 50.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_C4 min: 0.001 mean: 62.242 max: 382.566 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_soil_C4 min: 0.000 mean: 25.422 max: 183.688 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_canopy_C4 min: 0.000 mean: 36.820 max: 223.959 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Rn_C4 min: 49.119 mean: 398.425 max: 748.335 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Rn_soil_C4 min: 49.119 mean: 321.526 max: 605.894 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Rn_canopy_C4 min: 0.000 mean: 76.899 max: 267.313 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] started daylight ET upscaling
# [2026-02-27 10:40:33 INFO] completed daylight ET upscaling (elapsed: 0.01 seconds)
# [2026-02-27 10:40:33 INFO] completed processing BESS-JPL in 0.08 seconds
# [2026-02-27 10:40:33 INFO] variable Rn_BESS_Wm2 min: 49.119 mean: 398.425 max: 748.335 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Rn_BESS_Wm2 min: 49.119 mean: 398.425 max: 748.335 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_BESS_Wm2 min: 0.066 mean: 61.007 max: 381.956 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] calculating solar day of year
# [2026-02-27 10:40:33 INFO] calculating solar hour of day
# [2026-02-27 10:40:33 INFO] calculating daylight hours and sunrise hour
# [2026-02-27 10:40:33 INFO] variable LE_BESS_Wm2 min: 0.066 mean: 61.007 max: 381.956 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable GPP_inst_umol_m2_s min: 0.006 mean: 6.631 max: 39.888 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] starting Verma net radiation processing
# [2026-02-27 10:40:33 INFO] variable SWout_Wm2 min: 9.139 mean: 79.449 max: 298.413 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable SWnet_Wm2 min: 149.392 mean: 637.467 max: 1000.028 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LWin_Wm2 min: 223.160 mean: 317.615 max: 422.940 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LWout_Wm2 min: 316.593 mean: 469.764 max: 596.879 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Rn_Wm2 min: 26.361 mean: 485.319 max: 822.176 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] Verma net radiation processing complete in 0.00 seconds
# [2026-02-27 10:40:33 INFO] running Surface Temperature Initiated Closure
# [2026-02-27 10:40:33 INFO] variable Ms min: 0.000 mean: 0.162 max: 1.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] running STIC iteration 1 / 3
# [2026-02-27 10:40:33 INFO] using variable Priestley-Taylor alpha with mean: 1.124
# [2026-02-27 10:40:33 INFO] completed STIC iteration 1 / 3 with max LE change: 488.442 (0.0010056669998448342 seconds)
# [2026-02-27 10:40:33 INFO] variable SM_1 min: 0.000 mean: 0.077 max: 1.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable G_1 min: 2.991 mean: 66.072 max: 166.791 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_1 min: 2.572 mean: 177.286 max: 563.545 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] running STIC iteration 2 / 3
# [2026-02-27 10:40:33 INFO] using variable Priestley-Taylor alpha with mean: 1.178
# [2026-02-27 10:40:33 INFO] completed STIC iteration 2 / 3 with max LE change: 40.329 (0.003619791998062283 seconds)
# [2026-02-27 10:40:33 INFO] variable SM_2 min: 0.000 mean: 0.088 max: 1.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable G_2 min: 2.991 mean: 66.072 max: 166.791 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_2 min: 2.572 mean: 179.584 max: 563.545 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] running STIC iteration 3 / 3
# [2026-02-27 10:40:33 INFO] using variable Priestley-Taylor alpha with mean: 1.249
# [2026-02-27 10:40:33 INFO] completed STIC iteration 3 / 3 with max LE change: 32.488 (0.0057181669981218874 seconds)
# [2026-02-27 10:40:33 INFO] variable SM_3 min: 0.000 mean: 0.082 max: 1.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable G_3 min: 2.991 mean: 66.072 max: 166.791 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_3 min: 2.572 mean: 181.386 max: 563.545 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] started daily ET upscaling (STIC-JPL)
# [2026-02-27 10:40:33 INFO] completed daily ET upscaling (elapsed: 0.01 seconds)
# [2026-02-27 10:40:33 INFO] completed processing STIC-JPL in 0.03 seconds
# [2026-02-27 10:40:33 INFO] variable LE_STIC_Wm2 min: 2.572 mean: 181.386 max: 563.545 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ET_daylight_STIC_kg min: 0.038 mean: 2.559 max: 7.608 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_canoy_STIC_Wm2 min: 0.000 mean: 141.021 max: 475.505 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable G_STIC_Wm2 min: 2.991 mean: 66.072 max: 166.791 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_canopy_fraction_STIC min: 0.000 mean: 0.806 max: 1.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] running Priestley-Taylor JPL with Soil Moisture
# [2026-02-27 10:40:33 INFO] starting PT-JPL-SM model run
# [2026-02-27 10:40:33 INFO] using given optimum temperature (Topt_C)
# [2026-02-27 10:40:33 INFO] variable Topt_C min: 0.000 mean: 8.838 max: 20.450 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable fAPARmax min: 0.233 mean: 0.369 max: 0.604 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] using given air temperature (Ta_C)
# [2026-02-27 10:40:33 INFO] variable Ta_C min: 0.945 mean: 21.155 max: 36.229 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] using given relative humidity (RH)
# [2026-02-27 10:40:33 INFO] variable RH min: 0.071 mean: 0.261 max: 0.917 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] using given soil moisture (SM)
# [2026-02-27 10:40:33 INFO] variable soil_moisture min: -0.005 mean: 0.106 max: 0.633 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] using given field capacity
# [2026-02-27 10:40:33 INFO] variable field_capacity min: 0.190 mean: 0.273 max: 0.380 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] using given wilting point
# [2026-02-27 10:40:33 INFO] variable wilting_point min: 0.040 mean: 0.116 max: 0.160 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] using given canopy height
# [2026-02-27 10:40:33 INFO] variable canopy_height_meters min: 0.000 mean: 3.962 max: 25.743 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] using given net radiation (Rn_Wm2) for PT-JPL-SM processing
# [2026-02-27 10:40:33 INFO] variable Rn_Wm2 min: 26.361 mean: 485.319 max: 822.176 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] using given soil heat flux (G_Wm2)
# [2026-02-27 10:40:33 INFO] variable G min: 2.991 mean: 66.072 max: 166.791 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable fwet min: 0.000 mean: 0.018 max: 0.708 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable fREW min: 0.000 mean: 0.218 max: 1.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Topt_C min: 0.000 mean: 8.838 max: 20.450 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Topt_C min: 3.980 mean: 21.876 max: 36.229 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable epsilon min: 0.416 mean: 0.691 max: 0.832 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Rn_soil_Wm2 min: 15.041 mean: 302.261 max: 622.441 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_soil_Wm2 min: 0.023 mean: 28.867 max: 306.326 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Rn_canopy_Wm2 min: 11.319 mean: 183.057 max: 717.693 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable PET min: 21.640 mean: 366.701 max: 709.185 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable fTRM min: 0.146 mean: 0.884 max: 1.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_canopy_Wm2 min: 7.461 mean: 128.888 max: 500.539 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_interception_Wm2 min: 0.003 mean: 4.895 max: 106.274 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_Wm2 min: 8.660 mean: 162.650 max: 585.716 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] started daylight ET upscaling
# [2026-02-27 10:40:33 INFO] completed daylight ET upscaling (elapsed: 0.01 seconds)
# [2026-02-27 10:40:33 INFO] PT-JPL-SM model run complete (elapsed: 0.03 seconds)
# [2026-02-27 10:40:33 INFO] completed processing PT-JPL-SM in 0.03 seconds
# [2026-02-27 10:40:33 INFO] variable LE_PTJPLSM_Wm2 min: 8.660 mean: 162.650 max: 585.716 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ET_daylight_PTJPLSM_kg min: 0.093 mean: 2.213 max: 7.222 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable G_PTJPLSM min: 2.991 mean: 66.072 max: 166.791 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable EF_PTJPLSM min: 0.030 mean: 0.369 max: 0.918 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_canopy_PTJPLSM_Wm2 min: 7.461 mean: 128.888 max: 500.539 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_canopy_fraction_PTJPLSM min: 0.115 mean: 0.871 max: 1.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_soil_PTJPLSM_Wm2 min: 0.023 mean: 28.867 max: 306.326 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_soil_fraction_PTJPLSM min: 0.000 mean: 0.108 max: 0.880 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_interception_PTJPLSM_Wm2 min: 0.003 mean: 4.895 max: 106.274 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_interception_fraction_PTJPLSM min: 0.000 mean: 0.021 max: 0.686 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable PET_instantaneous_PTJPLSM_Wm2 min: 21.640 mean: 366.701 max: 709.185 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ESI_PTJPLSM min: 0.057 mean: 0.425 max: 0.997 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] running Penman-Monteith JPL
# [2026-02-27 10:40:33 INFO] variable Ta_C min: 0.945 mean: 21.155 max: 36.229 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Tmin_C min: 0.122 mean: 8.538 max: 27.538 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable IGBP (float32) with [ 1.  4.  5.  7.  8.  9. 10. 12.] unique values
# [2026-02-27 10:40:33 INFO] * 1.0: 23
# [2026-02-27 10:40:33 INFO] * 4.0: 16
# [2026-02-27 10:40:33 INFO] * 5.0: 5
# [2026-02-27 10:40:33 INFO] * 7.0: 37
# [2026-02-27 10:40:33 INFO] * 8.0: 52
# [2026-02-27 10:40:33 INFO] * 9.0: 5
# [2026-02-27 10:40:33 INFO] * 10.0: 126
# [2026-02-27 10:40:33 INFO] * 12.0: 6
# [2026-02-27 10:40:33 INFO] using given net radiation (Rn_Wm2) for PM-JPL processing
# [2026-02-27 10:40:33 INFO] variable Rn_Wm2 min: 26.361 mean: 485.319 max: 822.176 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable G_Wm2 min: 2.991 mean: 66.072 max: 166.791 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] calculating PM-MOD meteorology
# [2026-02-27 10:40:33 INFO] variable specific_humidity min: 0.001 mean: 0.004 max: 0.017 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable rho_kgm3 min: 1.139 mean: 1.403 max: 1.893 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Cp_Jkg min: 1005.749 mean: 1008.102 max: 1019.066 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable delta_Pa min: 47.219 mean: 162.416 max: 328.422 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable fwet (float32) with [9.9999997e-05 2.7603585e-01 7.0808017e-01] unique values
# [2026-02-27 10:40:33 INFO] * 1e-04: 268
# [2026-02-27 10:40:33 INFO] * 0.27603585: 1
# [2026-02-27 10:40:33 INFO] * 0.7080802: 1
# [2026-02-27 10:40:33 INFO] calculating PM-MOD resistances
# [2026-02-27 10:40:33 INFO] variable gl_sh (float32) with [0.01 0.02 0.04 0.08] unique values
# [2026-02-27 10:40:33 INFO] * 0.01: 16
# [2026-02-27 10:40:33 INFO] * 0.02: 132
# [2026-02-27 10:40:33 INFO] * 0.04: 65
# [2026-02-27 10:40:33 INFO] * 0.08: 57
# [2026-02-27 10:40:33 INFO] variable rhc (float64) with [   9.63469032  109.50309962 2000.        ] unique values
# [2026-02-27 10:40:33 INFO] * 9.63469031727548: 1
# [2026-02-27 10:40:33 INFO] * 109.50309961854944: 1
# [2026-02-27 10:40:33 INFO] * 2000.0: 268
# [2026-02-27 10:40:33 INFO] variable rrc min: 171.589 mean: 245.488 max: 334.254 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable rhrc min: 9.268 mean: 217.146 max: 286.390 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable gl_e_wv (float32) with [0.01 0.02 0.04 0.08] unique values
# [2026-02-27 10:40:33 INFO] * 0.01: 16
# [2026-02-27 10:40:33 INFO] * 0.02: 132
# [2026-02-27 10:40:33 INFO] * 0.04: 65
# [2026-02-27 10:40:33 INFO] * 0.08: 57
# [2026-02-27 10:40:33 INFO] variable rvc (float64) with [   9.63469032  109.50309962 2000.        ] unique values
# [2026-02-27 10:40:33 INFO] * 9.63469031727548: 1
# [2026-02-27 10:40:33 INFO] * 109.50309961854944: 1
# [2026-02-27 10:40:33 INFO] * 2000.0: 268
# [2026-02-27 10:40:33 INFO] variable Ac min: 21.059 mean: 294.731 max: 815.430 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_interception_Wm2 min: 0.001 mean: 0.834 max: 147.689 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable rcorr min: 0.914 mean: 1.165 max: 1.575 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable CL (float32) with [0.0025 0.0028 0.0032 0.0065 0.007 ] unique values
# [2026-02-27 10:40:33 INFO] * 0.0025: 5
# [2026-02-27 10:40:33 INFO] * 0.0028: 16
# [2026-02-27 10:40:33 INFO] * 0.0032: 23
# [2026-02-27 10:40:33 INFO] * 0.0065: 94
# [2026-02-27 10:40:33 INFO] * 0.007: 132
# [2026-02-27 10:40:33 INFO] variable Tmin_open (float32) with [ 8.31  8.8   9.5   9.94 11.39 12.02] unique values
# [2026-02-27 10:40:33 INFO] * 8.31: 23
# [2026-02-27 10:40:33 INFO] * 8.8: 37
# [2026-02-27 10:40:33 INFO] * 9.5: 5
# [2026-02-27 10:40:33 INFO] * 9.94: 16
# [2026-02-27 10:40:33 INFO] * 11.39: 57
# [2026-02-27 10:40:33 INFO] * 12.02: 132
# [2026-02-27 10:40:33 INFO] variable Tmin_closed (float32) with [-8. -7. -6.] unique values
# [2026-02-27 10:40:33 INFO] * -8.0: 249
# [2026-02-27 10:40:33 INFO] * -7.0: 5
# [2026-02-27 10:40:33 INFO] * -6.0: 16
# [2026-02-27 10:40:33 INFO] variable Tmin_C min: 0.122 mean: 8.538 max: 27.538 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable mTmin min: 0.384 mean: 0.819 max: 1.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable VPD_open (float32) with [650.] unique values
# [2026-02-27 10:40:33 INFO] * 650.0: 270
# [2026-02-27 10:40:33 INFO] variable VPD_closed (float32) with [2900. 3000. 3500. 3600. 4200. 4400. 4500.] unique values
# [2026-02-27 10:40:33 INFO] * 2900.0: 21
# [2026-02-27 10:40:33 INFO] * 3000.0: 23
# [2026-02-27 10:40:33 INFO] * 3500.0: 52
# [2026-02-27 10:40:33 INFO] * 3600.0: 5
# [2026-02-27 10:40:33 INFO] * 4200.0: 126
# [2026-02-27 10:40:33 INFO] * 4400.0: 37
# [2026-02-27 10:40:33 INFO] * 4500.0: 6
# [2026-02-27 10:40:33 INFO] variable mVPD min: 0.000 mean: 0.581 max: 1.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable gs1 min: 0.000 mean: 0.003 max: 0.009 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Gcu min: 0.000 mean: 0.000 max: 0.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Cc min: 0.001 mean: 0.003 max: 0.020 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable rs min: 50.835 mean: 840.265 max: 2000.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable rh min: 50.835 mean: 840.265 max: 2000.000 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable rr min: 171.589 mean: 245.488 max: 334.254 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ra min: 11.651 mean: 32.398 max: 72.359 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_canopy_Wm2 min: 4.034 mean: 88.931 max: 443.946 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable RBL_max (float32) with [ 45.  50.  55.  95. 100.] unique values
# [2026-02-27 10:40:33 INFO] * 45.0: 57
# [2026-02-27 10:40:33 INFO] * 50.0: 132
# [2026-02-27 10:40:33 INFO] * 55.0: 37
# [2026-02-27 10:40:33 INFO] * 95.0: 28
# [2026-02-27 10:40:33 INFO] * 100.0: 16
# [2026-02-27 10:40:33 INFO] variable RBL_min (float32) with [20. 25. 65.] unique values
# [2026-02-27 10:40:33 INFO] * 20.0: 169
# [2026-02-27 10:40:33 INFO] * 25.0: 57
# [2026-02-27 10:40:33 INFO] * 65.0: 44
# [2026-02-27 10:40:33 INFO] variable rtotc min: 20.000 mean: 45.100 max: 96.552 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable rtot min: 22.116 mean: 51.957 max: 127.227 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable rrs min: 171.589 mean: 245.488 max: 334.254 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ras min: 20.018 mean: 41.990 max: 91.981 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable Asoil min: 0.000 mean: 134.984 max: 450.366 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable wet_soil_evaporation_Wm2 min: 0.000 mean: 0.024 max: 0.091 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable potential_soil_evaporation_Wm2 min: 0.000 mean: 238.998 max: 907.998 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable fSM min: 0.000 mean: 0.011 max: 0.946 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_soil_Wm2 min: 0.000 mean: 0.214 max: 10.612 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable LE_Wm2 min: 5.510 mean: 89.752 max: 443.967 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] started daylight ET upscaling (PMJPL)
# [2026-02-27 10:40:33 INFO] completed daylight ET upscaling (PMJPL)
# [2026-02-27 10:40:33 INFO] completed processing PM-JPL in 0.05 seconds
# [2026-02-27 10:40:33 INFO] variable LE_PMJPL_Wm2 min: 5.510 mean: 89.752 max: 443.967 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ET_daylight_PMJPL_kg min: 0.061 mean: 1.258 max: 6.064 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable G_PMJPL_Wm2 min: 2.991 mean: 66.072 max: 166.791 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] variable ET_daylight_kg min: 0.232 mean: 1.595 max: 5.417 nan: 0.00% (nan)
# [2026-02-27 10:40:33 INFO] JET table processing complete (0.401 seconds)
#       Unnamed: 0      ID vegetation climate    STICinst   BESSinst  MOD16inst  \
# 15            15  US-xAB        ENF     Csb  141.635670  168.24043  402.81810
# 17            17  US-xAB        ENF     Csb    1.881266  163.94730  301.40400
# 18            18  US-xAB        ENF     Csb    3.135606  246.87700  614.51480
# 19            19  US-xAB        ENF     Csb  311.482820  290.73126  672.27510
# 20            20  US-xAB        ENF     Csb   51.920338   95.28810  116.67136
# ...          ...     ...        ...     ...         ...        ...        ...
# 992          992  US-xML        DBF     Dfb  417.831120  706.93066  523.92740
# 994          994  US-xML        DBF     Dfb  161.558200  306.15277  420.44678
# 1001        1001  US-UiB        CRO     Dfa   93.876100  251.38747  238.71077
# 1020        1020  US-ARM        CRO     Cfa   80.255005    0.00000  180.10085
# 1021        1021  US-ARM        CRO     Cfa  126.236190    0.00000  199.79102
#
#       PTJPLSMinst      ETinst  ETinstUncertainty  ...  ET_daylight_PMJPL_kg  \
# 15      159.71700  139.016083         107.183200  ...              2.801589
# 17      179.13661  131.273636         106.525215  ...              2.783958
# 18      405.50497  366.056641         222.890230  ...              4.063770
# 19      478.82382  439.821228         153.787670  ...              4.385870
# 20       73.20884  232.693512          24.038680  ...              4.020650
# ...           ...         ...                ...  ...                   ...
# 992     310.69684  356.174072         148.624050  ...              3.500136
# 994     206.48576  237.659103          98.727560  ...              3.192998
# 1001    198.90399  106.316444          67.694800  ...              0.541116
# 1020    211.28325  164.581390          84.672410  ...              0.724623
# 1021    232.13673  281.860535          89.163790  ...              0.210093
#
#       G_PMJPL_Wm2      G_Wm2  LE_instantaneous_Wm2  ET_daylight_kg  \
# 15      24.232924  24.232924            235.004622        3.344676
# 17      13.888571  13.888571            208.788803        3.634896
# 18      33.053500  33.053500            375.255018        4.865916
# 19      42.253985  42.253985            376.522864        4.622162
# 20       2.990681   2.990681            118.701271        3.149331
# ...           ...        ...                   ...             ...
# 992     29.141253  29.141253            375.417816        3.438145
# 994     21.272888  21.272888            282.035514        2.848649
# 1001    76.673547  76.673547             89.036541        1.108975
# 1020    68.376990  68.376990            118.650430        1.399859
# 1021    82.524278  82.524278             94.174657        1.031016
#
#       ET_uncertainty  GPP_inst_g_m2_s  ET_canopy_inst_kg_m2_s       WUE  \
# 15          0.811325         0.000151                0.000100  1.519952
# 17          1.116933         0.000108                0.000072  1.497547
# 18          1.183193         0.000291                0.000173  1.677395
# 19          1.329070         0.000294                0.000204  1.436631
# 20          0.754490         0.000095                0.000010  9.130613
# ...              ...              ...                     ...       ...
# 992         0.941759         0.000233                0.000133  1.751269
# 994         1.064079         0.000138                0.000100  1.382509
# 1001        1.255443         0.000053                0.000022  2.366093
# 1020        1.418580         0.000048                0.000035  1.376374
# 1021        1.489555         0.000044                0.000038  1.149460
#
#       AuxiliaryNWP
# 15
# 17
# 18
# 19
# 20
# ...            ...
# 992
# 994
# 1001
# 1020
# 1021
#
# [270 rows x 181 columns]

# %%
# Create side-by-side scatter plots comparing uncalibrated vs calibrated meteorological variables
from sklearn.metrics import r2_score, mean_squared_error

# Dictionary of variables to compare with their display names and units
met_variables = {
    'Ta_C': {'name': 'Air Temperature', 'unit': '°C', 'xlim': None, 'ylim': None},
    'RH': {'name': 'Relative Humidity', 'unit': '', 'xlim': [0, 1], 'ylim': [0, 1]},
    'SM': {'name': 'Soil Moisture', 'unit': 'm³/m³', 'xlim': [0, 0.6], 'ylim': [0, 0.6]}
}

for var, info in met_variables.items():
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))
    
    # Filter valid data
    if var in input_df.columns and var in processed_uncalibrated.columns and var in processed_calibrated.columns:
        valid_idx = input_df[var].notna() & processed_uncalibrated[var].notna() & processed_calibrated[var].notna()
        
        if valid_idx.sum() == 0:
            print(f"No valid data for {var}")
            plt.close()
            continue
        
        input_vals = input_df.loc[valid_idx, var]
        uncal_vals = processed_uncalibrated.loc[valid_idx, var]
        cal_vals = processed_calibrated.loc[valid_idx, var]
        st_c = processed_uncalibrated.loc[valid_idx, 'ST_C']
        
        # LEFT: Original vs Uncalibrated (should be 1:1)
        sc1 = ax1.scatter(x=input_vals, y=uncal_vals, 
                   c=st_c, cmap='jet', s=10, alpha=0.6)
        
        # Calculate correlation
        if len(input_vals) > 1:
            r2_uncal = r2_score(input_vals, uncal_vals)
            rmse_uncal = np.sqrt(mean_squared_error(input_vals, uncal_vals))
            ax1.annotate(f"$R^2$ = {r2_uncal:.3f}\nRMSE = {rmse_uncal:.3f}",
                        xy=(0.05, 0.95), xycoords='axes fraction',
                        ha='left', va='top', fontsize=10,
                        bbox=dict(boxstyle='round', fc='white', ec='gray', alpha=0.7))
        
        # 1:1 line
        lims = [min(input_vals.min(), uncal_vals.min()), max(input_vals.max(), uncal_vals.max())]
        ax1.plot(lims, lims, 'k-', linewidth=1, label='1:1 Line')
        ax1.set_xlabel(f'Original {info["name"]} {info["unit"]}')
        ax1.set_ylabel(f'Uncalibrated {info["name"]} {info["unit"]}')
        ax1.set_title(f'WITHOUT Calibration\n(Should be 1:1)')
        ax1.grid(True, alpha=0.3)
        ax1.legend()
        if info['xlim']:
            ax1.set_xlim(info['xlim'])
            ax1.set_ylim(info['ylim'])
        
        # RIGHT: Original vs Calibrated (shows adjustment)
        sc2 = ax2.scatter(x=input_vals, y=cal_vals,
                        c=st_c, cmap='jet', s=10, alpha=0.6)
        
        # Calculate correlation
        if len(input_vals) > 1:
            r2_cal = r2_score(input_vals, cal_vals)
            rmse_cal = np.sqrt(mean_squared_error(input_vals, cal_vals))
            ax2.annotate(f"$R^2$ = {r2_cal:.3f}\nRMSE = {rmse_cal:.3f}",
                        xy=(0.05, 0.95), xycoords='axes fraction',
                        ha='left', va='top', fontsize=10,
                        bbox=dict(boxstyle='round', fc='white', ec='gray', alpha=0.7))
        
        # 1:1 line
        lims = [min(input_vals.min(), cal_vals.min()), max(input_vals.max(), cal_vals.max())]
        ax2.plot(lims, lims, 'k-', linewidth=1, label='1:1 Line')
        ax2.set_xlabel(f'Original {info["name"]} {info["unit"]}')
        ax2.set_ylabel(f'Calibrated {info["name"]} {info["unit"]}')
        ax2.set_title(f'WITH Calibration\n(Shows Adjustment)')
        ax2.grid(True, alpha=0.3)
        ax2.legend()
        if info['xlim']:
            ax2.set_xlim(info['xlim'])
            ax2.set_ylim(info['ylim'])
        
        # Add colorbar
        fig.subplots_adjust(right=0.9)
        cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])
        fig.colorbar(sc2, cax=cbar_ax, label='Surface Temperature (°C)')
        
        plt.suptitle(f'{info["name"]} Calibration Adjustment', fontsize=14, y=0.98)
        
        if SAVE_PLOTS:
            plt.savefig(f'{var}_Calibration_Comparison.jpeg', format='jpeg', bbox_inches='tight', dpi=150)
            plt.savefig(f'{var}_Calibration_Comparison.svg', format='svg', bbox_inches='tight')
        
        plt.tight_layout()
        plt.show()
        
        # Print summary
        print(f"\n{info['name']} Calibration Summary:")
        print(f"  Mean Original: {input_vals.mean():.3f} {info['unit']}")
        print(f"  Mean Uncalibrated: {uncal_vals.mean():.3f} {info['unit']}")
        print(f"  Mean Calibrated: {cal_vals.mean():.3f} {info['unit']}")
        print(f"  Mean Adjustment: {(cal_vals.mean() - input_vals.mean()):.3f} {info['unit']}")
    else:
        print(f"Variable {var} not found in all dataframes")
        plt.close()
# Out:
# /var/folders/hk/35_x93nx79vg1zmd2fy1vcbr0000gq/T/ipykernel_58201/360642084.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Air Temperature Calibration Summary:
#   Mean Original: 22.343 °C
#   Mean Uncalibrated: 22.343 °C
#   Mean Calibrated: 21.155 °C
#   Mean Adjustment: -1.187 °C
# /var/folders/hk/35_x93nx79vg1zmd2fy1vcbr0000gq/T/ipykernel_58201/360642084.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Relative Humidity Calibration Summary:
#   Mean Original: 0.388
#   Mean Uncalibrated: 0.388
#   Mean Calibrated: 0.261
#   Mean Adjustment: -0.126
# /var/folders/hk/35_x93nx79vg1zmd2fy1vcbr0000gq/T/ipykernel_58201/360642084.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Soil Moisture Calibration Summary:
#   Mean Original: 0.144 m³/m³
#   Mean Uncalibrated: 0.144 m³/m³
#   Mean Calibrated: 0.106 m³/m³
#   Mean Adjustment: -0.038 m³/m³

# %% [markdown]
# ## Accuracy Comparison: Uncalibrated vs Calibrated
#
# Comparing model accuracy with and without calibration applied to meteorological inputs (Ta, RH, SM).

# %% [markdown]
# Examining the accuracy of model estimates compared to ground data.

# %%
from sklearn.metrics import r2_score, mean_squared_error

insitu_columns = sorted([column for column in processed_calibrated.columns if "insitu" in column])

for insitu_variable in insitu_columns:
    try:
        output_variable = insitu_variable.replace("insitu_", "")
        print(f"analyzing {model_name} accuracy for {output_variable} compared to {insitu_variable}")
        
        x_variable = insitu_variable
        y_variable = output_variable

        # Create figure with 2 subplots (uncalibrated vs calibrated)
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))
        
        # ===== LEFT PLOT: UNCALIBRATED =====
        valid_data_uncal = processed_uncalibrated[[x_variable, y_variable, 'ST_C']].dropna()
        
        if len(valid_data_uncal) > 0:
            sc1 = ax1.scatter(
                x=valid_data_uncal[x_variable],
                y=valid_data_uncal[y_variable],
                c=valid_data_uncal.ST_C,
                cmap="jet",
                s=5
            )
            
            # Calculate 5% and 95% tails
            x_5th, x_95th = np.percentile(valid_data_uncal[x_variable], [5, 95])
            y_5th, y_95th = np.percentile(valid_data_uncal[y_variable], [5, 95])
            min_val = min(x_5th, y_5th)
            max_val = max(x_95th, y_95th)
            
            # 1:1 line
            ax1.plot([min_val, max_val], [min_val, max_val], color='black', linestyle='-', linewidth=1, label='1:1 Line')
            
            # OLS regression
            coefs = np.polyfit(valid_data_uncal[x_variable], valid_data_uncal[y_variable], 1)
            ols_x = np.array([min_val, max_val])
            ols_y = coefs[0] * ols_x + coefs[1]
            ax1.plot(ols_x, ols_y, color='black', linestyle='--', linewidth=1, label='OLS Fit')
            
            # Calculate R² and RMSE
            y_true = valid_data_uncal[y_variable]
            y_pred = coefs[0] * valid_data_uncal[x_variable] + coefs[1]
            r2 = r2_score(y_true, y_pred)
            rmse = np.sqrt(mean_squared_error(y_true, y_pred))
            
            ax1.annotate(f"$R^2$ = {r2:.2f}\nRMSE = {rmse:.1f}",
                        xy=(0.05, 0.05), xycoords='axes fraction',
                        ha='left', va='bottom', fontsize=10,
                        bbox=dict(boxstyle='round', fc='white', ec='gray', alpha=0.7))
            
            ax1.grid(True, zorder=0)
            ax1.set_xlabel(f"In-Situ {output_variable}")
            ax1.set_ylabel(f"{model_name} {output_variable}")
            ax1.set_title(f"WITHOUT Calibration\nIn-Situ vs {model_name} {output_variable}")
            ax1.legend(loc='upper right')
        
        # ===== RIGHT PLOT: CALIBRATED =====
        valid_data_cal = processed_calibrated[[x_variable, y_variable, 'ST_C']].dropna()
        
        if len(valid_data_cal) > 0:
            sc2 = ax2.scatter(
                x=valid_data_cal[x_variable],
                y=valid_data_cal[y_variable],
                c=valid_data_cal.ST_C,
                cmap="jet",
                s=5
            )
            
            # Calculate 5% and 95% tails
            x_5th, x_95th = np.percentile(valid_data_cal[x_variable], [5, 95])
            y_5th, y_95th = np.percentile(valid_data_cal[y_variable], [5, 95])
            min_val = min(x_5th, y_5th)
            max_val = max(x_95th, y_95th)
            
            # 1:1 line
            ax2.plot([min_val, max_val], [min_val, max_val], color='black', linestyle='-', linewidth=1, label='1:1 Line')
            
            # OLS regression
            coefs = np.polyfit(valid_data_cal[x_variable], valid_data_cal[y_variable], 1)
            ols_x = np.array([min_val, max_val])
            ols_y = coefs[0] * ols_x + coefs[1]
            ax2.plot(ols_x, ols_y, color='black', linestyle='--', linewidth=1, label='OLS Fit')
            
            # Calculate R² and RMSE
            y_true = valid_data_cal[y_variable]
            y_pred = coefs[0] * valid_data_cal[x_variable] + coefs[1]
            r2 = r2_score(y_true, y_pred)
            rmse = np.sqrt(mean_squared_error(y_true, y_pred))
            
            ax2.annotate(f"$R^2$ = {r2:.2f}\nRMSE = {rmse:.1f}",
                        xy=(0.05, 0.05), xycoords='axes fraction',
                        ha='left', va='bottom', fontsize=10,
                        bbox=dict(boxstyle='round', fc='white', ec='gray', alpha=0.7))
            
            ax2.grid(True, zorder=0)
            ax2.set_xlabel(f"In-Situ {output_variable}")
            ax2.set_ylabel(f"{model_name} {output_variable}")
            ax2.set_title(f"WITH Calibration\nIn-Situ vs {model_name} {output_variable}")
            ax2.legend(loc='upper right')
        
        # Add shared colorbar
        fig.subplots_adjust(right=0.9)
        cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])
        fig.colorbar(sc2, cax=cbar_ax, label="ECOSTRESS Surface Temperature (°C)")
        
        plt.suptitle(f"Calibration Impact on {output_variable} Accuracy", fontsize=14, y=0.98)
        
        if SAVE_PLOTS:
            plt.savefig(f"Calibration Comparison of {output_variable}.jpeg", format='jpeg', bbox_inches='tight', dpi=150)
            plt.savefig(f"Calibration Comparison of {output_variable}.svg", format='svg', bbox_inches='tight')
        
        plt.tight_layout()
        plt.show()
        
    except Exception as e:
        print(f"Error processing {output_variable}: {e}")
        import traceback
        traceback.print_exc()
        continue
# Out:
# analyzing JET accuracy for ET_daylight_kg compared to insitu_ET_daylight_kg
# /var/folders/hk/35_x93nx79vg1zmd2fy1vcbr0000gq/T/ipykernel_58201/1028714077.py:115: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# analyzing JET accuracy for G_Wm2 compared to insitu_G_Wm2
# /var/folders/hk/35_x93nx79vg1zmd2fy1vcbr0000gq/T/ipykernel_58201/1028714077.py:115: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# analyzing JET accuracy for H_Wm2 compared to insitu_H_Wm2
# /var/folders/hk/35_x93nx79vg1zmd2fy1vcbr0000gq/T/ipykernel_58201/1028714077.py:115: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# analyzing JET accuracy for LE_Wm2 compared to insitu_LE_Wm2
# /var/folders/hk/35_x93nx79vg1zmd2fy1vcbr0000gq/T/ipykernel_58201/1028714077.py:115: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# analyzing JET accuracy for LE_daylight_Wm2 compared to insitu_LE_daylight_Wm2
# Error processing LE_daylight_Wm2: "['LE_daylight_Wm2'] not in index"
# analyzing JET accuracy for RH compared to insitu_RH
# Traceback (most recent call last):
#   File "/var/folders/hk/35_x93nx79vg1zmd2fy1vcbr0000gq/T/ipykernel_58201/1028714077.py", line 17, in <module>
#     valid_data_uncal = processed_uncalibrated[[x_variable, y_variable, 'ST_C']].dropna()
#                        ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.12/site-packages/pandas/core/frame.py", line 4384, in __getitem__
#     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.12/site-packages/pandas/core/indexes/base.py", line 6302, in _get_indexer_strict
#     self._raise_if_missing(keyarr, indexer, axis_name)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.12/site-packages/pandas/core/indexes/base.py", line 6355, in _raise_if_missing
#     raise KeyError(f"{not_found} not in index")
# KeyError: "['LE_daylight_Wm2'] not in index"
# /var/folders/hk/35_x93nx79vg1zmd2fy1vcbr0000gq/T/ipykernel_58201/1028714077.py:115: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# analyzing JET accuracy for Rn_Wm2 compared to insitu_Rn_Wm2
# /var/folders/hk/35_x93nx79vg1zmd2fy1vcbr0000gq/T/ipykernel_58201/1028714077.py:115: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# analyzing JET accuracy for Rn_daylight_Wm2 compared to insitu_Rn_daylight_Wm2
# Error processing Rn_daylight_Wm2: "['Rn_daylight_Wm2'] not in index"
# analyzing JET accuracy for SWin_Wm2 compared to insitu_SWin_Wm2
# Traceback (most recent call last):
#   File "/var/folders/hk/35_x93nx79vg1zmd2fy1vcbr0000gq/T/ipykernel_58201/1028714077.py", line 17, in <module>
#     valid_data_uncal = processed_uncalibrated[[x_variable, y_variable, 'ST_C']].dropna()
#                        ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.12/site-packages/pandas/core/frame.py", line 4384, in __getitem__
#     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.12/site-packages/pandas/core/indexes/base.py", line 6302, in _get_indexer_strict
#     self._raise_if_missing(keyarr, indexer, axis_name)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.12/site-packages/pandas/core/indexes/base.py", line 6355, in _raise_if_missing
#     raise KeyError(f"{not_found} not in index")
# KeyError: "['Rn_daylight_Wm2'] not in index"
# /var/folders/hk/35_x93nx79vg1zmd2fy1vcbr0000gq/T/ipykernel_58201/1028714077.py:115: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# analyzing JET accuracy for Ta_C compared to insitu_Ta_C
# /var/folders/hk/35_x93nx79vg1zmd2fy1vcbr0000gq/T/ipykernel_58201/1028714077.py:115: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
# RH vs LE_Wm2 scatter plots: uncalibrated vs calibrated
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6), sharex=True, sharey=True)

# Uncalibrated
df_uncal = processed_uncalibrated[["RH", "LE_Wm2"]].dropna()
ax1.scatter(df_uncal["RH"], df_uncal["LE_Wm2"], s=12, alpha=0.7, color="black")
ax1.set_title("WITHOUT Calibration")
ax1.set_xlabel("Relative Humidity (RH)")
ax1.set_ylabel("LE_Wm2")
ax1.grid(True, alpha=0.3)

# Calibrated
df_cal = processed_calibrated[["RH", "LE_Wm2"]].dropna()
ax2.scatter(df_cal["RH"], df_cal["LE_Wm2"], s=12, alpha=0.7, color="blue")
ax2.set_title("WITH Calibration")
ax2.set_xlabel("Relative Humidity (RH)")
ax2.grid(True, alpha=0.3)

plt.suptitle("RH vs LE_Wm2: Uncalibrated vs Calibrated", fontsize=14, y=0.98)
plt.tight_layout()

if SAVE_PLOTS:
    plt.savefig("RH_vs_LE_Wm2_Calibration_Comparison.jpeg", format="jpeg", bbox_inches="tight", dpi=150)
    plt.savefig("RH_vs_LE_Wm2_Calibration_Comparison.svg", format="svg", bbox_inches="tight")

plt.show()

# %% [markdown]
# # Net Radiation Accuracy Comparison: BESS vs Verma (With/Without Calibration)

# %%
insitu_variable = "insitu_Rn_Wm2"

for output_variable in ["Rn_BESS_Wm2", "Rn_verma_Wm2"]:
    try:
        print(f"analyzing {model_name} accuracy for {output_variable} compared to {insitu_variable}")
        
        x_variable = insitu_variable
        y_variable = output_variable

        # Create figure with 2 subplots
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))
        
        # ===== LEFT: UNCALIBRATED =====
        valid_data_uncal = processed_uncalibrated[[x_variable, y_variable, 'ST_C']].dropna()
        
        if len(valid_data_uncal) > 0:
            sc1 = ax1.scatter(
                x=valid_data_uncal[x_variable],
                y=valid_data_uncal[y_variable],
                c=valid_data_uncal.ST_C,
                cmap="jet",
                s=5
            )
            
            x_5th, x_95th = np.percentile(valid_data_uncal[x_variable], [5, 95])
            y_5th, y_95th = np.percentile(valid_data_uncal[y_variable], [5, 95])
            min_val = min(x_5th, y_5th)
            max_val = max(x_95th, y_95th)
            
            ax1.plot([min_val, max_val], [min_val, max_val], color='black', linestyle='-', linewidth=1, label='1:1 Line')
            
            coefs = np.polyfit(valid_data_uncal[x_variable], valid_data_uncal[y_variable], 1)
            ols_x = np.array([min_val, max_val])
            ols_y = coefs[0] * ols_x + coefs[1]
            ax1.plot(ols_x, ols_y, color='black', linestyle='--', linewidth=1, label='OLS Fit')
            
            y_true = valid_data_uncal[y_variable]
            y_pred = coefs[0] * valid_data_uncal[x_variable] + coefs[1]
            r2 = r2_score(y_true, y_pred)
            rmse = np.sqrt(mean_squared_error(y_true, y_pred))
            
            ax1.annotate(f"$R^2$ = {r2:.2f}\nRMSE = {rmse:.1f}",
                        xy=(0.05, 0.05), xycoords='axes fraction',
                        ha='left', va='bottom', fontsize=10,
                        bbox=dict(boxstyle='round', fc='white', ec='gray', alpha=0.7))
            
            ax1.grid(True, zorder=0)
            ax1.set_xlabel(f"In-Situ {output_variable}")
            ax1.set_ylabel(f"{model_name} {output_variable}")
            ax1.set_title(f"WITHOUT Calibration\n{output_variable}")
            ax1.legend(loc='upper right')
        
        # ===== RIGHT: CALIBRATED =====
        valid_data_cal = processed_calibrated[[x_variable, y_variable, 'ST_C']].dropna()
        
        if len(valid_data_cal) > 0:
            sc2 = ax2.scatter(
                x=valid_data_cal[x_variable],
                y=valid_data_cal[y_variable],
                c=valid_data_cal.ST_C,
                cmap="jet",
                s=5
            )
            
            x_5th, x_95th = np.percentile(valid_data_cal[x_variable], [5, 95])
            y_5th, y_95th = np.percentile(valid_data_cal[y_variable], [5, 95])
            min_val = min(x_5th, y_5th)
            max_val = max(x_95th, y_95th)
            
            ax2.plot([min_val, max_val], [min_val, max_val], color='black', linestyle='-', linewidth=1, label='1:1 Line')
            
            coefs = np.polyfit(valid_data_cal[x_variable], valid_data_cal[y_variable], 1)
            ols_x = np.array([min_val, max_val])
            ols_y = coefs[0] * ols_x + coefs[1]
            ax2.plot(ols_x, ols_y, color='black', linestyle='--', linewidth=1, label='OLS Fit')
            
            y_true = valid_data_cal[y_variable]
            y_pred = coefs[0] * valid_data_cal[x_variable] + coefs[1]
            r2 = r2_score(y_true, y_pred)
            rmse = np.sqrt(mean_squared_error(y_true, y_pred))
            
            ax2.annotate(f"$R^2$ = {r2:.2f}\nRMSE = {rmse:.1f}",
                        xy=(0.05, 0.05), xycoords='axes fraction',
                        ha='left', va='bottom', fontsize=10,
                        bbox=dict(boxstyle='round', fc='white', ec='gray', alpha=0.7))
            
            ax2.grid(True, zorder=0)
            ax2.set_xlabel(f"In-Situ {output_variable}")
            ax2.set_ylabel(f"{model_name} {output_variable}")
            ax2.set_title(f"WITH Calibration\n{output_variable}")
            ax2.legend(loc='upper right')
        
        # Colorbar
        fig.subplots_adjust(right=0.9)
        cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])
        fig.colorbar(sc2, cax=cbar_ax, label="ECOSTRESS Surface Temperature (°C)")
        
        plt.suptitle(f"Calibration Impact on {output_variable}", fontsize=14, y=0.98)
        
        if SAVE_PLOTS:
            plt.savefig(f"Calibration Comparison of {output_variable}.jpeg", format='jpeg', bbox_inches='tight', dpi=150)
            plt.savefig(f"Calibration Comparison of {output_variable}.svg", format='svg', bbox_inches='tight')
        
        plt.tight_layout()
        plt.show()
    except Exception as e:
        print(f"Error processing {output_variable}: {e}")
        import traceback
        traceback.print_exc()
        continue
# Out:
# analyzing JET accuracy for Rn_BESS_Wm2 compared to insitu_Rn_Wm2
# /var/folders/hk/35_x93nx79vg1zmd2fy1vcbr0000gq/T/ipykernel_58201/2034817545.py:104: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# analyzing JET accuracy for Rn_verma_Wm2 compared to insitu_Rn_Wm2
# /var/folders/hk/35_x93nx79vg1zmd2fy1vcbr0000gq/T/ipykernel_58201/2034817545.py:104: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
insitu_variable = "insitu_LE_Wm2"

output_variables = [
    "LE_BESS_Wm2",
    "LE_STIC_Wm2",
    "LE_PTJPLSM_Wm2",
    "LE_PMJPL_Wm2",
    "LE_Wm2"
]

for output_variable in output_variables:
    try:
        print(f"analyzing {model_name} accuracy for {output_variable} compared to {insitu_variable}")
        
        x_variable = insitu_variable
        y_variable = output_variable

        # Create figure with 2 subplots
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))
        
        # ===== LEFT: UNCALIBRATED =====
        valid_data_uncal = processed_uncalibrated[[x_variable, y_variable, 'ST_C']].dropna()
        
        if len(valid_data_uncal) > 0:
            sc1 = ax1.scatter(
                x=valid_data_uncal[x_variable],
                y=valid_data_uncal[y_variable],
                c=valid_data_uncal.ST_C,
                cmap="jet",
                s=5
            )
            
            x_5th, x_95th = np.percentile(valid_data_uncal[x_variable], [5, 95])
            y_5th, y_95th = np.percentile(valid_data_uncal[y_variable], [5, 95])
            min_val = min(x_5th, y_5th)
            max_val = max(x_95th, y_95th)
            
            ax1.plot([min_val, max_val], [min_val, max_val], color='black', linestyle='-', linewidth=1, label='1:1 Line')
            
            coefs = np.polyfit(valid_data_uncal[x_variable], valid_data_uncal[y_variable], 1)
            ols_x = np.array([min_val, max_val])
            ols_y = coefs[0] * ols_x + coefs[1]
            ax1.plot(ols_x, ols_y, color='black', linestyle='--', linewidth=1, label='OLS Fit')
            
            y_true = valid_data_uncal[y_variable]
            y_pred = coefs[0] * valid_data_uncal[x_variable] + coefs[1]
            r2 = r2_score(y_true, y_pred)
            rmse = np.sqrt(mean_squared_error(y_true, y_pred))
            
            ax1.annotate(f"$R^2$ = {r2:.2f}\nRMSE = {rmse:.1f}",
                        xy=(0.05, 0.05), xycoords='axes fraction',
                        ha='left', va='bottom', fontsize=10,
                        bbox=dict(boxstyle='round', fc='white', ec='gray', alpha=0.7))
            
            ax1.grid(True, zorder=0)
            ax1.set_xlabel(f"In-Situ {insitu_variable}")
            ax1.set_ylabel(f"{model_name} {output_variable}")
            ax1.set_title(f"WITHOUT Calibration\n{output_variable}")
            ax1.legend(loc='upper right')
        
        # ===== RIGHT: CALIBRATED =====
        valid_data_cal = processed_calibrated[[x_variable, y_variable, 'ST_C']].dropna()
        
        if len(valid_data_cal) > 0:
            sc2 = ax2.scatter(
                x=valid_data_cal[x_variable],
                y=valid_data_cal[y_variable],
                c=valid_data_cal.ST_C,
                cmap="jet",
                s=5
            )
            
            x_5th, x_95th = np.percentile(valid_data_cal[x_variable], [5, 95])
            y_5th, y_95th = np.percentile(valid_data_cal[y_variable], [5, 95])
            min_val = min(x_5th, y_5th)
            max_val = max(x_95th, y_95th)
            
            ax2.plot([min_val, max_val], [min_val, max_val], color='black', linestyle='-', linewidth=1, label='1:1 Line')
            
            coefs = np.polyfit(valid_data_cal[x_variable], valid_data_cal[y_variable], 1)
            ols_x = np.array([min_val, max_val])
            ols_y = coefs[0] * ols_x + coefs[1]
            ax2.plot(ols_x, ols_y, color='black', linestyle='--', linewidth=1, label='OLS Fit')
            
            y_true = valid_data_cal[y_variable]
            y_pred = coefs[0] * valid_data_cal[x_variable] + coefs[1]
            r2 = r2_score(y_true, y_pred)
            rmse = np.sqrt(mean_squared_error(y_true, y_pred))
            
            ax2.annotate(f"$R^2$ = {r2:.2f}\nRMSE = {rmse:.1f}",
                        xy=(0.05, 0.05), xycoords='axes fraction',
                        ha='left', va='bottom', fontsize=10,
                        bbox=dict(boxstyle='round', fc='white', ec='gray', alpha=0.7))
            
            ax2.grid(True, zorder=0)
            ax2.set_xlabel(f"In-Situ {insitu_variable}")
            ax2.set_ylabel(f"{model_name} {output_variable}")
            ax2.set_title(f"WITH Calibration\n{output_variable}")
            ax2.legend(loc='upper right')
        
        # Colorbar
        fig.subplots_adjust(right=0.9)
        cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])
        fig.colorbar(sc2, cax=cbar_ax, label="ECOSTRESS Surface Temperature (°C)")
        
        plt.suptitle(f"Calibration Impact on {output_variable}", fontsize=14, y=0.98)
        
        if SAVE_PLOTS:
            plt.savefig(f"Calibration Comparison of {output_variable}.jpeg", format='jpeg', bbox_inches='tight', dpi=150)
            plt.savefig(f"Calibration Comparison of {output_variable}.svg", format='svg', bbox_inches='tight')
        
        plt.tight_layout()
        plt.show()
        
    except Exception as e:
        print(f"Error processing {output_variable}: {e}")
        import traceback
        traceback.print_exc()
        continue
# Out:
# analyzing JET accuracy for LE_BESS_Wm2 compared to insitu_LE_Wm2
# /var/folders/hk/35_x93nx79vg1zmd2fy1vcbr0000gq/T/ipykernel_58201/175198646.py:112: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# analyzing JET accuracy for LE_STIC_Wm2 compared to insitu_LE_Wm2
# /var/folders/hk/35_x93nx79vg1zmd2fy1vcbr0000gq/T/ipykernel_58201/175198646.py:112: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# analyzing JET accuracy for LE_PTJPLSM_Wm2 compared to insitu_LE_Wm2
# /var/folders/hk/35_x93nx79vg1zmd2fy1vcbr0000gq/T/ipykernel_58201/175198646.py:112: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# analyzing JET accuracy for LE_PMJPL_Wm2 compared to insitu_LE_Wm2
# /var/folders/hk/35_x93nx79vg1zmd2fy1vcbr0000gq/T/ipykernel_58201/175198646.py:112: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# analyzing JET accuracy for LE_Wm2 compared to insitu_LE_Wm2
# /var/folders/hk/35_x93nx79vg1zmd2fy1vcbr0000gq/T/ipykernel_58201/175198646.py:112: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# ## Surface Temperature vs Net Radiation Comparison (With/Without Calibration)
#
# Side-by-side comparison showing how calibration affects the relationship between surface temperature and net radiation.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

# LEFT: Uncalibrated
ax1.scatter(x=processed_uncalibrated.ST_C, y=processed_uncalibrated.Rn_Wm2, color='black', s=10, zorder=5)
ax1.grid(True, zorder=0)
ax1.set_xlabel("ECOSTRESS Surface Temperature (°C)")
ax1.set_ylabel(f"{model_name} Net Radiation (W/m$^2$)")
ax1.set_title(f"WITHOUT Calibration\nSurface Temperature vs Net Radiation")

# RIGHT: Calibrated
ax2.scatter(x=processed_calibrated.ST_C, y=processed_calibrated.Rn_Wm2, color='blue', s=10, zorder=5)
ax2.grid(True, zorder=0)
ax2.set_xlabel("ECOSTRESS Surface Temperature (°C)")
ax2.set_ylabel(f"{model_name} Net Radiation (W/m$^2$)")
ax2.set_title(f"WITH Calibration\nSurface Temperature vs Net Radiation")

plt.suptitle(f"Calibration Impact on Surface Temperature vs Net Radiation", fontsize=14, y=0.98)

if SAVE_PLOTS:
    plt.savefig(f"Calibration Comparison Surface Temperature to Net Radiation.jpeg", format='jpeg', bbox_inches='tight', dpi=150)
    plt.savefig(f"Calibration Comparison Surface Temperature to Net Radiation.svg", format='svg', bbox_inches='tight')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Surface Temperature vs Evapotranspiration Comparison (With/Without Calibration)
#
# Side-by-side comparison showing how calibration affects the relationship between surface temperature and evapotranspiration.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

# LEFT: Uncalibrated
ax1.scatter(x=processed_uncalibrated.ST_C, y=processed_uncalibrated.ET_daylight_kg, color='black', s=10, zorder=5)
ax1.grid(True, zorder=0)
ax1.set_xlabel("ECOSTRESS Surface Temperature (°C)")
ax1.set_ylabel(f"{model_name} Evapotranspiration (mm/day)")
ax1.set_title(f"WITHOUT Calibration\nSurface Temperature vs Evapotranspiration")

# RIGHT: Calibrated  
ax2.scatter(x=processed_calibrated.ST_C, y=processed_calibrated.ET_daylight_kg, color='blue', s=10, zorder=5)
ax2.grid(True, zorder=0)
ax2.set_xlabel("ECOSTRESS Surface Temperature (°C)")
ax2.set_ylabel(f"{model_name} Evapotranspiration (mm/day)")
ax2.set_title(f"WITH Calibration\nSurface Temperature vs Evapotranspiration")

plt.suptitle(f"Calibration Impact on Surface Temperature vs Evapotranspiration", fontsize=14, y=0.98)

if SAVE_PLOTS:
    plt.savefig(f"Calibration Comparison Surface Temperature to Evapotranspiration.jpeg", format='jpeg', bbox_inches='tight', dpi=150)
    plt.savefig(f"Calibration Comparison Surface Temperature to Evapotranspiration.svg", format='svg', bbox_inches='tight')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Summary Statistics: Calibration Impact
#
# Calculate and display summary statistics comparing uncalibrated vs calibrated model performance.

# %%
# Calculate summary statistics for key variables
summary_data = []

insitu_columns = sorted([column for column in processed_calibrated.columns if "insitu" in column])

for insitu_variable in insitu_columns:
    output_variable = insitu_variable.replace("insitu_", "")
    
    if output_variable not in processed_uncalibrated.columns or output_variable not in processed_calibrated.columns:
        continue
    
    # Uncalibrated metrics
    valid_uncal = processed_uncalibrated[[insitu_variable, output_variable]].dropna()
    if len(valid_uncal) > 0:
        r2_uncal = r2_score(valid_uncal[insitu_variable], valid_uncal[output_variable])
        rmse_uncal = np.sqrt(mean_squared_error(valid_uncal[insitu_variable], valid_uncal[output_variable]))
    else:
        r2_uncal = np.nan
        rmse_uncal = np.nan
    
    # Calibrated metrics
    valid_cal = processed_calibrated[[insitu_variable, output_variable]].dropna()
    if len(valid_cal) > 0:
        r2_cal = r2_score(valid_cal[insitu_variable], valid_cal[output_variable])
        rmse_cal = np.sqrt(mean_squared_error(valid_cal[insitu_variable], valid_cal[output_variable]))
    else:
        r2_cal = np.nan
        rmse_cal = np.nan
    
    # Calculate improvements
    r2_improvement = r2_cal - r2_uncal
    rmse_improvement = rmse_uncal - rmse_cal  # Positive means improvement (lower RMSE)
    rmse_percent_improvement = (rmse_improvement / rmse_uncal) * 100 if rmse_uncal > 0 else np.nan
    
    summary_data.append({
        'Variable': output_variable,
        'R² (Uncalibrated)': f"{r2_uncal:.3f}",
        'R² (Calibrated)': f"{r2_cal:.3f}",
        'ΔR²': f"{r2_improvement:+.3f}",
        'RMSE (Uncalibrated)': f"{rmse_uncal:.2f}",
        'RMSE (Calibrated)': f"{rmse_cal:.2f}",
        'ΔRMSE': f"{rmse_improvement:+.2f}",
        'RMSE % Improvement': f"{rmse_percent_improvement:.1f}%"
    })

summary_df = pd.DataFrame(summary_data)
print("\n" + "="*100)
print("CALIBRATION IMPACT SUMMARY")
print("="*100)
print(summary_df.to_string(index=False))
print("="*100)
print("\nNote: Positive ΔR² indicates improvement (higher R²)")
print("      Positive ΔRMSE indicates improvement (lower RMSE)")
print("      Positive % Improvement indicates calibration improved accuracy")
print("="*100)
# Out:
# ====================================================================================================
# CALIBRATION IMPACT SUMMARY
# ====================================================================================================
#       Variable R² (Uncalibrated) R² (Calibrated)    ΔR² RMSE (Uncalibrated) RMSE (Calibrated)  ΔRMSE RMSE % Improvement
# ET_daylight_kg             0.537           0.562 +0.024                1.02              1.00  +0.03               2.6%
#          G_Wm2             0.435           0.451 +0.016               46.43             45.76  +0.67               1.4%
#          H_Wm2             0.323           0.294 -0.029              102.90            105.11  -2.21              -2.1%
#         LE_Wm2             0.558           0.602 +0.044               68.86             65.33  +3.53               5.1%
#             RH             0.033           0.701 +0.668                0.17              0.09  +0.07              44.4%
#         Rn_Wm2             0.527           0.644 +0.117              108.59             94.18 +14.41              13.3%
#       SWin_Wm2             0.812           0.812 +0.000               90.92             90.92  +0.00               0.0%
#           Ta_C             0.813           0.914 +0.101                3.06              2.08  +0.98              32.1%
# ====================================================================================================
#
# Note: Positive ΔR² indicates improvement (higher R²)
#       Positive ΔRMSE indicates improvement (lower RMSE)
#       Positive % Improvement indicates calibration improved accuracy
# ====================================================================================================

# %% [markdown]
# ## Visual Comparison of Calibration Impact
#
# Bar charts showing R² and RMSE improvements from calibration.

# %%
# Create visual comparison of calibration impact
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

# Extract numeric values for plotting
variables = []
r2_uncal_values = []
r2_cal_values = []
rmse_uncal_values = []
rmse_cal_values = []

for item in summary_data:
    variables.append(item['Variable'])
    r2_uncal_values.append(float(item['R² (Uncalibrated)']))
    r2_cal_values.append(float(item['R² (Calibrated)']))
    rmse_uncal_values.append(float(item['RMSE (Uncalibrated)']))
    rmse_cal_values.append(float(item['RMSE (Calibrated)']))

x = np.arange(len(variables))
width = 0.35

# R² comparison
bars1 = ax1.bar(x - width/2, r2_uncal_values, width, label='Uncalibrated', color='gray', alpha=0.7)
bars2 = ax1.bar(x + width/2, r2_cal_values, width, label='Calibrated', color='blue', alpha=0.7)
ax1.set_xlabel('Variable')
ax1.set_ylabel('R² Score')
ax1.set_title('R² Comparison: Uncalibrated vs Calibrated')
ax1.set_xticks(x)
ax1.set_xticklabels(variables, rotation=45, ha='right')
ax1.legend()
ax1.grid(True, alpha=0.3, axis='y')
ax1.set_ylim([0, 1])

# RMSE comparison  
bars3 = ax2.bar(x - width/2, rmse_uncal_values, width, label='Uncalibrated', color='gray', alpha=0.7)
bars4 = ax2.bar(x + width/2, rmse_cal_values, width, label='Calibrated', color='blue', alpha=0.7)
ax2.set_xlabel('Variable')
ax2.set_ylabel('RMSE')
ax2.set_title('RMSE Comparison: Uncalibrated vs Calibrated')
ax2.set_xticks(x)
ax2.set_xticklabels(variables, rotation=45, ha='right')
ax2.legend()
ax2.grid(True, alpha=0.3, axis='y')

plt.suptitle('Calibration Impact on Model Performance Metrics', fontsize=14, y=0.98)
plt.tight_layout()

if SAVE_PLOTS:
    plt.savefig(f"Calibration Impact Metrics Comparison.jpeg", format='jpeg', bbox_inches='tight', dpi=150)
    plt.savefig(f"Calibration Impact Metrics Comparison.svg", format='svg', bbox_inches='tight')

plt.show()

print("\nInterpretation:")
print("- LEFT: Higher R² bars indicate better model fit (calibrated should be higher)")
print("- RIGHT: Lower RMSE bars indicate better accuracy (calibrated should be lower)")
# Out:
# Interpretation:
# - LEFT: Higher R² bars indicate better model fit (calibrated should be higher)
# - RIGHT: Lower RMSE bars indicate better accuracy (calibrated should be lower)
